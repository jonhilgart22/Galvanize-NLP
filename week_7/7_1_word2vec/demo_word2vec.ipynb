# %% [markdown]
# ----
# Apply word2vec to dataset
# -----
#
# Overview:
#
# 1. Download some training data
# 1. Setup word2vec model in TensorFlow
# 1. Train on the data a bit
# 1. Visualize the result
#
# This notebook is based on a [TensorFlow tutorial](https://github.com/tensorflow/tensorflow/blob/r0.10/tensorflow/examples/tutorials/word2vec/word2vec_basic.py).

# %%
reset -fs

# %%
import collections
import math
import os
from pprint import pprint
import random
import urllib.request
import zipfile

import matplotlib.pyplot as plt
import numpy as np
import tensorflow as tf 
from sklearn.manifold import TSNE

# %matplotlib inline

# %% [markdown]
# ----
# Step 1: Download the data.
# ----

# %%
url = 'http://mattmahoney.net/dc/'

def maybe_download(filename, expected_bytes):
    """Download a file if not present, and make sure it's the right size."""
    if not os.path.exists(filename):
        filename, _ = urllib.request.urlretrieve(url + filename, filename)
    
    statinfo = os.stat(filename)
    if statinfo.st_size == expected_bytes:
        print('Found and verified', filename)
    else:
        print(statinfo.st_size)
        raise Exception(
            'Failed to verify ' + filename + '. Can you get to it with a browser?')
    
    return filename

filename = maybe_download('text8.zip', 31344016)
# Out:
# Found and verified text8.zip

# %% [markdown]
# ☝️ While this code is running, preview the code ahead.

# %%
# Read the data into a list of strings.
def read_data(filename):
    """Extract the first file enclosed in a zip file as a list of words"""
    with zipfile.ZipFile(filename) as f:
        data = tf.compat.as_str(f.read(f.namelist()[0])).split()
    return data

words = read_data(filename)
print('Dataset size: {:,} words'.format(len(words)))
# Out:
# Dataset size: 17,005,207 words

# %%
# Let's have a peek at the head
words[:5]
# Out:
# ['anarchism', 'originated', 'as', 'a', 'term']

# %%
# Let's have a peek at the tail
words[-5:]
# Out:
# ['one', 'nine', 'six', 'five', 'b']

# %% [markdown]
# Notice: None of the words are capitalized and there is no punctuation.
#
# Preprocessing is an art. It depends on your raw data and how you plan to use your final data. You might want to encode ngrams, instead of just splitting all items into unigrams.

# %% [markdown]
# -----
# Step 2: Build the dictionary
# -----

# %%
vocabulary_size = 50000

def build_dataset(words):
    """ Replace rare words with UNK token which stands for "unknown".
    It is called a dustbin category, aka sweep the small count items into a single group.
    """
    count = [['UNK', -1]]
    count.extend(collections.Counter(words).most_common(vocabulary_size - 1))
    dictionary = dict()
    for word, _ in count:
        dictionary[word] = len(dictionary)
    data = list()
    unk_count = 0
    for word in words:
        if word in dictionary:
            index = dictionary[word]
        else:
            index = 0  # dictionary['UNK']
            unk_count += 1
        data.append(index)
    count[0][1] = unk_count
    reverse_dictionary = dict(zip(dictionary.values(), dictionary.keys()))
    return data, count, dictionary, reverse_dictionary

# %%
data, count, dictionary, reverse_dictionary = build_dataset(words)
del words  # Reduce memory by getting rid of the "heavy" list of strings

# %%
data[:5] # An index of each word (as it appears in order) to its rank. Therefore we don't have reference the string
# Out:
# [5241, 3082, 12, 6, 195]

# %%
dictionary['UNK']
# Out:
# 0

# %%
dictionary['the'] # word: rank
# Out:
# 1

# %%
reverse_dictionary[42] # rank: word
# Out:
# 'but'

# %%
print('Most common words:') 
pprint(count[:5])
# Out:
# Most common words:
# [['UNK', 418391],
#  ('the', 1061396),
#  ('of', 593677),
#  ('and', 416629),
#  ('one', 411764)]

# %%
print('Most least words:')
pprint(count[-5:])
# Out:
# Most least words:
# [('aikman', 9), ('persson', 9), ('refuel', 9), ('orcus', 9), ('langston', 9)]

# %% [markdown]
# ----
# Step 3: Function to generate a training batch for the skip-gram model.
# -----

# %%
data_index = 0

def generate_batch(batch_size, num_skips, skip_window):
    global data_index
    assert batch_size % num_skips == 0
    assert num_skips <= 2 * skip_window
    batch = np.ndarray(shape=(batch_size), dtype=np.int32)
    labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
    span = 2 * skip_window + 1 # [ skip_window target skip_window ]
    buffer = collections.deque(maxlen=span)
    for _ in range(span):
        buffer.append(data[data_index])
        data_index = (data_index + 1) % len(data)
    for i in range(batch_size // num_skips):
        target = skip_window  # target label at the center of the buffer
        targets_to_avoid = [ skip_window ]
        for j in range(num_skips):
            while target in targets_to_avoid:
                target = random.randint(0, span - 1)
            targets_to_avoid.append(target)
            batch[i * num_skips + j] = buffer[skip_window]
            labels[i * num_skips + j, 0] = buffer[target]
        buffer.append(data[data_index])
        data_index = (data_index + 1) % len(data)
    return batch, labels

# %%
batch, labels = generate_batch(batch_size=8, 
                               num_skips=2, 
                               skip_window=1)

# %% [markdown]
# ----
# Step 4: Build and train a skip-gram model.
# -----

# %%
batch_size = 128
embedding_size = 128  # Dimension of the embedding vector.
skip_window = 1       # How many words to consider left and right.
num_skips = 2         # How many times to reuse an input to generate a label.

# We pick a random validation set to sample nearest neighbors. Here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent.
valid_size = 16     # Random set of words to evaluate similarity on.
valid_window = 100  # Only pick dev samples in the head of the distribution.
valid_examples = np.random.choice(valid_window, valid_size, replace=False)
num_sampled = 64    # Number of negative examples to sample.

# %%
# TensorFlow setup
graph = tf.Graph()

with graph.as_default():

    # Input data
    train_inputs = tf.placeholder(tf.int32, shape=[batch_size])
    train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
    valid_dataset = tf.constant(valid_examples, dtype=tf.int32)

    # Ops and variables pinned to the CPU because of missing GPU implementation
    with tf.device('/cpu:0'):
        # Look up embeddings for inputs.
        embeddings = tf.Variable(
            tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
        embed = tf.nn.embedding_lookup(embeddings, train_inputs)

        # Construct the variables for the NCE loss
        nce_weights = tf.Variable(
            tf.truncated_normal([vocabulary_size, embedding_size],
                                stddev=1.0 / math.sqrt(embedding_size)))
        nce_biases = tf.Variable(tf.zeros([vocabulary_size]))

    # Compute the average NCE loss for the batch.
    # tf.nce_loss automatically draws a new sample of the negative labels each
    # time we evaluate the loss.
    loss = tf.reduce_mean(
      tf.nn.nce_loss(nce_weights, nce_biases, embed, train_labels,
                     num_sampled, vocabulary_size))

    # Construct the SGD optimizer using a learning rate of 1.0.
    optimizer = tf.train.GradientDescentOptimizer(1.0).minimize(loss)

    # Compute the cosine similarity between minibatch examples and all embeddings.
    norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
    normalized_embeddings = embeddings / norm
    valid_embeddings = tf.nn.embedding_lookup(
      normalized_embeddings, valid_dataset)
    similarity = tf.matmul(
      valid_embeddings, normalized_embeddings, transpose_b=True)

    # Add variable initializer.
    init = tf.initialize_all_variables()

# %% [markdown]
# ----
# Step 5: Begin training.
# -----

# %%
num_steps = 100000 #100001

with tf.Session(graph=graph) as session:
    # We must initialize all variables before we use them.
    init.run()
    print("Initialized")

    average_loss = 0
    for step in range(num_steps):
        batch_inputs, batch_labels = generate_batch(
            batch_size, num_skips, skip_window)
        feed_dict = {train_inputs : batch_inputs, train_labels : batch_labels}

        # We perform one update step by evaluating the optimizer op (including it
        # in the list of returned values for session.run()
        _, loss_val = session.run([optimizer, loss], feed_dict=feed_dict)
        average_loss += loss_val

        if step % 2000 == 0:
            if step > 0:
                average_loss /= 2000
            # The average loss is an estimate of the loss over the last 2000 batches.
            print("Average loss at step ", step, ": ", average_loss)
            average_loss = 0

        # Note that this is expensive (~20% slowdown if computed every 500 steps)
        if step % 10000 == 0:
            sim = similarity.eval()
            for i in range(valid_size):
                valid_word = reverse_dictionary[valid_examples[i]]
                top_k = 8 # number of nearest neighbors
                nearest = (-sim[i, :]).argsort()[1:top_k+1]
                log_str = "Nearest to '%s':" % valid_word
                for k in range(top_k):
                    close_word = reverse_dictionary[nearest[k]]
                    log_str = "%s %s," % (log_str, close_word)
                print(log_str)
    final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step  0 :  303.637634277
# Nearest to 'all': moser, toni, jonathan, raceway, njazidja, opulent, executives, aam,
# Nearest to 'be': recycling, products, assuring, diadem, punishing, denounce, hassan, honouring,
# Nearest to 'when': surveys, sects, predictably, optative, vyacheslav, shock, demeaning, bikes,
# Nearest to 'after': discography, mooring, warheads, expectancy, concur, succeeded, cossacks, afro,
# Nearest to 'called': bureaucracies, indians, lynx, mini, vse, philharmonic, kurdish, plurals,
# Nearest to 'system': purer, mummified, anticonvulsants, cynicism, hydrosphere, schaeffer, competitively, springboard,
# Nearest to 'th': marquee, unemployment, blooms, ends, crusading, lori, aboriginals, patria,
# Nearest to 'no': scriptwriter, otherworldly, herr, agar, handshake, necessities, ezln, eyre,
# Nearest to 'by': employer, grin, publique, bayreuth, pers, cantor, ptah, signalled,
# Nearest to 'its': farouk, nameserver, ncs, lutheranism, edgerton, alone, lebeau, sequences,
# Nearest to 'not': hey, errand, fluorescence, justus, vacant, ayyash, ephemeral, currying,
# Nearest to 'which': rda, unexpectedly, alsatian, litigation, overlordship, fk, alchemy, brisance,
# Nearest to 'than': annapolis, doubled, now, disobeyed, luigi, jakob, cataloging, pacts,
# Nearest to 'to': anakin, sidemen, capitulated, watford, idb, yo, morality, lpg,
# Nearest to 'that': imre, wuxia, golem, anthropological, hellenes, nonaligned, revue, plugging,
# Nearest to 'on': unenforceable, navigator, hotline, sparing, civilisation, kinematic, weser, strelitz,
# Average loss at step  2000 :  114.5597345
# Average loss at step  4000 :  52.47830709
# Average loss at step  6000 :  33.3059478915
# Average loss at step  8000 :  23.1510096383
# Average loss at step  10000 :  17.4375624107
# Nearest to 'all': jonathan, mode, domain, moser, frequency, vernacular, interests, individuals,
# Nearest to 'be': tract, have, diadem, avowed, punishing, asser, volcano, deity,
# Nearest to 'when': yin, is, antwerp, percent, polyhedra, eight, was, agnes,
# Nearest to 'after': succeeded, warheads, blocks, apache, greensboro, ministers, discography, for,
# Nearest to 'called': indians, chiefly, rodin, plaque, asbestos, and, medieval, promotion,
# Nearest to 'system': polyhedra, serious, sartre, fate, consonantal, plane, s, wasn,
# Nearest to 'th': eight, ends, acc, blooms, zero, defend, basis, severe,
# Nearest to 'no': cdot, unfortunately, weapons, albatross, become, arthur, interstate, relatively,
# Nearest to 'by': in, and, polyhedra, to, employer, of, for, zero,
# Nearest to 'its': the, escape, a, tennis, sequences, distant, alone, qualifications,
# Nearest to 'not': sweyn, accident, cicero, hey, tm, a, network, aquila,
# Nearest to 'which': unlimited, piranha, but, alchemy, there, and, our, it,
# Nearest to 'than': annapolis, aorta, valuable, doubled, feeling, interstate, presented, united,
# Nearest to 'to': and, in, chain, for, by, abet, with, interstate,
# Nearest to 'that': aoc, hellenes, aquila, and, said, argo, in, illegitimate,
# Nearest to 'on': in, for, two, between, and, of, one, three,
# Average loss at step  12000 :  13.9676442995
# Average loss at step  14000 :  11.8333064896
# Average loss at step  16000 :  9.63730370915
# Average loss at step  18000 :  8.93595481145
# Average loss at step  20000 :  7.87959888816
# Nearest to 'all': jonathan, beef, trinomial, mode, domain, abatis, spp, three,
# Nearest to 'be': have, tract, was, avowed, vcs, diadem, were, recycling,
# Nearest to 'when': is, was, yin, at, antwerp, eight, polyhedra, as,
# Nearest to 'after': in, discography, blocks, afro, and, greensboro, for, of,
# Nearest to 'called': and, mini, UNK, indians, chiefly, hypertext, plaque, medieval,
# Nearest to 'system': s, infinitely, serious, polyhedra, sartre, fate, wasn, plane,
# Nearest to 'th': eight, three, seven, ends, spp, acc, unemployment, blooms,
# Nearest to 'no': zef, unfortunately, agar, a, cdot, weapons, become, stylized,
# Nearest to 'by': in, was, and, as, polyhedra, with, zero, at,
# Nearest to 'its': the, a, their, escape, his, sequences, some, abatis,
# Nearest to 'not': it, to, also, sweyn, that, tm, cicero, avenging,
# Nearest to 'which': and, it, but, one, that, unlimited, this, there,
# Nearest to 'than': akh, annapolis, aorta, valuable, three, doubled, palestine, united,
# Nearest to 'to': for, in, and, chain, by, nine, with, into,
# Nearest to 'that': which, tangle, aoc, this, hellenes, trinomial, argo, saxophone,
# Nearest to 'on': in, for, at, between, trinomial, from, and, into,
# Average loss at step  22000 :  7.4739601934
# Average loss at step  24000 :  6.90505875206
# Average loss at step  26000 :  6.28017816222
# Average loss at step  28000 :  6.21762953722
# Average loss at step  30000 :  6.00151280224
# Nearest to 'all': recitative, three, jonathan, mode, trinomial, controlling, domain, beef,
# Nearest to 'be': have, by, tract, are, were, is, was, avowed,
# Nearest to 'when': is, was, eight, four, as, will, antwerp, polyhedra,
# Nearest to 'after': and, in, discography, expectancy, afro, before, seven, greensboro,
# Nearest to 'called': and, mini, hypertext, chiefly, medieval, plaque, indians, waveforms,
# Nearest to 'system': hebrides, infinitely, eisenhower, competitively, fate, serious, wasn, neurologic,
# Nearest to 'th': eight, seven, three, unemployment, four, blooms, albury, spp,
# Nearest to 'no': a, herr, zef, agar, weapons, unfortunately, cdot, stylized,
# Nearest to 'by': as, in, was, and, with, were, for, polyhedra,
# Nearest to 'its': the, their, his, a, sequences, interstate, escape, some,
# Nearest to 'not': it, also, to, avenging, albury, sweyn, graduated, batters,
# Nearest to 'which': that, but, this, and, it, one, four, there,
# Nearest to 'than': akh, or, valuable, annapolis, aorta, doubled, presented, queens,
# Nearest to 'to': for, chain, not, and, nine, with, can, abet,
# Nearest to 'that': which, tangle, this, also, trinomial, said, but, hellenes,
# Nearest to 'on': in, at, from, between, trinomial, for, and, two,
# Average loss at step  32000 :  5.97586670995
# Average loss at step  34000 :  5.71940664792
# Average loss at step  36000 :  5.38329503906
# Average loss at step  38000 :  5.50287790823
# Average loss at step  40000 :  5.53044143975
# Nearest to 'all': recitative, three, jonathan, beef, ruin, sqrt, manipulation, trinomial,
# Nearest to 'be': have, by, was, were, are, tract, is, avowed,
# Nearest to 'when': is, was, thibetanus, as, at, in, eight, five,
# Nearest to 'after': in, before, discography, afro, expectancy, greensboro, for, seven,
# Nearest to 'called': mini, and, hypertext, chiefly, plaque, medieval, waveforms, indians,
# Nearest to 'system': prism, infinitely, hebrides, eisenhower, serious, fate, anticonvulsants, wasn,
# Nearest to 'th': eight, three, seven, zero, unemployment, four, six, albury,
# Nearest to 'no': a, herr, weapons, zef, agar, nine, stylized, cdot,
# Nearest to 'by': was, as, with, be, in, and, were, prism,
# Nearest to 'its': their, the, his, sequences, khanna, interstate, stages, some,
# Nearest to 'not': it, also, to, always, albury, bongo, avenging, we,
# Nearest to 'which': that, this, but, it, and, also, thibetanus, wct,
# Nearest to 'than': or, akh, valuable, annapolis, aorta, presented, disobeyed, pest,
# Nearest to 'to': nine, not, can, chain, and, for, cpa, grabs,
# Nearest to 'that': which, this, tangle, but, also, trinomial, ceremonies, said,
# Nearest to 'on': in, at, trinomial, from, between, for, into, prism,
# Average loss at step  42000 :  5.43069675982
# Average loss at step  44000 :  5.36454178596
# Average loss at step  46000 :  5.42056985843
# Average loss at step  48000 :  5.18279469556
# Average loss at step  50000 :  4.99119123137
# Nearest to 'all': three, michelob, recitative, sqrt, saguinus, both, regards, jonathan,
# Nearest to 'be': have, by, were, was, tract, are, been, nine,
# Nearest to 'when': was, as, is, thibetanus, five, if, four, but,
# Nearest to 'after': before, during, in, for, expectancy, and, greensboro, building,
# Nearest to 'called': mini, callithrix, hypertext, UNK, medieval, chiefly, rodin, waveforms,
# Nearest to 'system': prism, mitral, eisenhower, infinitely, hebrides, fate, headphones, wasn,
# Nearest to 'th': eight, six, seven, three, nine, four, unemployment, albury,
# Nearest to 'no': a, herr, weapons, zef, mitral, nine, maoism, unfortunately,
# Nearest to 'by': eight, nine, was, six, be, polyhedra, as, five,
# Nearest to 'its': their, his, the, her, dipyramid, sequences, khanna, interstate,
# Nearest to 'not': it, also, to, we, they, bongo, you, often,
# Nearest to 'which': that, this, but, it, also, thibetanus, cebus, michelob,
# Nearest to 'than': or, akh, valuable, aorta, rw, disobeyed, annapolis, presented,
# Nearest to 'to': nine, cebus, can, chain, tamarin, marmoset, cpa, six,
# Nearest to 'that': which, this, but, tangle, also, mitral, controlling, microcebus,
# Nearest to 'on': in, at, from, between, trinomial, callithrix, into, tamarin,
# Average loss at step  52000 :  4.96795345116
# Average loss at step  54000 :  5.17985600138
# Average loss at step  56000 :  5.10771701646
# Average loss at step  58000 :  4.91483564746
# Average loss at step  60000 :  4.91726076853
# Nearest to 'all': saguinus, three, both, michelob, recitative, parts, some, beit,
# Nearest to 'be': have, by, been, were, are, is, was, tract,
# Nearest to 'when': was, is, if, but, as, thibetanus, antwerp, and,
# Nearest to 'after': before, during, and, in, at, thaler, when, expectancy,
# Nearest to 'called': and, mini, callithrix, waveforms, hypertext, medieval, indians, chiefly,
# Nearest to 'system': prism, mitral, eisenhower, michelob, hebrides, fate, infinitely, plane,
# Nearest to 'th': six, eight, nine, seven, three, four, five, unemployment,
# Nearest to 'no': a, herr, weapons, zef, mitral, stylized, replayed, handshake,
# Nearest to 'by': be, was, nine, with, as, polyhedra, eight, been,
# Nearest to 'its': their, the, his, her, dipyramid, interstate, some, khanna,
# Nearest to 'not': to, also, often, it, they, we, bongo, you,
# Nearest to 'which': that, this, but, it, also, thibetanus, one, wct,
# Nearest to 'than': or, akh, valuable, disobeyed, much, cpl, rw, isambard,
# Nearest to 'to': nine, not, cebus, can, through, microcebus, tamarin, eight,
# Nearest to 'that': which, this, but, also, mitral, tangle, microcebus, controlling,
# Nearest to 'on': in, at, between, trinomial, callithrix, from, upon, two,
# Average loss at step  62000 :  4.93951243261
# Average loss at step  64000 :  5.02538133353
# Average loss at step  66000 :  4.92354495561
# Average loss at step  68000 :  4.91198874366
# Average loss at step  70000 :  4.94777663445
# Nearest to 'all': both, saguinus, recitative, these, michelob, three, some, two,
# Nearest to 'be': have, been, by, was, were, are, is, avowed,
# Nearest to 'when': if, was, but, iit, thibetanus, as, until, is,
# Nearest to 'after': before, during, when, building, in, as, at, six,
# Nearest to 'called': and, mini, callithrix, pontificia, waveforms, aba, hypertext, rodin,
# Nearest to 'system': prism, kyushu, mitral, iit, fate, michelob, hebrides, plane,
# Nearest to 'th': eight, six, seven, five, nine, unemployment, crusading, three,
# Nearest to 'no': herr, a, mitral, weapons, zef, replayed, handshake, it,
# Nearest to 'by': as, was, be, in, with, been, were, polyhedra,
# Nearest to 'its': their, his, the, her, dipyramid, interstate, tamias, some,
# Nearest to 'not': it, often, also, they, to, you, we, graduated,
# Nearest to 'which': that, this, but, it, also, and, wct, thibetanus,
# Nearest to 'than': or, akh, valuable, much, cpl, disobeyed, aorta, pest,
# Nearest to 'to': can, nine, not, through, cebus, for, may, would,
# Nearest to 'that': which, this, but, iit, pontificia, however, tangle, also,
# Nearest to 'on': in, at, from, trinomial, upon, callithrix, between, within,
# Average loss at step  72000 :  4.88755635619
# Average loss at step  74000 :  4.87933665955
# Average loss at step  76000 :  4.78106624341
# Average loss at step  78000 :  4.82291884792
# Average loss at step  80000 :  4.79741407454
# Nearest to 'all': both, these, some, saguinus, michelob, recitative, beit, sqrt,
# Nearest to 'be': have, been, by, were, was, is, are, nine,
# Nearest to 'when': if, was, but, as, iit, until, after, while,
# Nearest to 'after': before, during, when, building, thaler, greensboro, at, so,
# Nearest to 'called': and, callithrix, mini, waveforms, pontificia, aba, considered, chiefly,
# Nearest to 'system': prism, kyushu, mitral, iit, systems, michelob, hebrides, fate,
# Nearest to 'th': six, seven, eight, nine, crusading, unemployment, blooms, spp,
# Nearest to 'no': a, herr, weapons, mitral, handshake, replayed, stylized, abet,
# Nearest to 'by': was, be, polyhedra, with, as, been, were, royce,
# Nearest to 'its': their, his, the, her, dipyramid, interstate, tamias, microsite,
# Nearest to 'not': it, also, often, to, they, never, you, still,
# Nearest to 'which': that, this, but, also, it, and, thibetanus, wct,
# Nearest to 'than': or, akh, much, valuable, disobeyed, cpl, rw, ecclesiastical,
# Nearest to 'to': nine, not, rooks, for, through, would, cebus, tamarin,
# Nearest to 'that': which, this, but, iit, however, rooks, tangle, pontificia,
# Nearest to 'on': in, at, upon, between, from, trinomial, callithrix, thaler,
# Average loss at step  82000 :  4.69234935713
# Average loss at step  84000 :  4.79788299847
# Average loss at step  86000 :  4.71440514863
# Average loss at step  88000 :  4.73648157227
# Average loss at step  90000 :  4.76996925211
# Nearest to 'all': both, these, some, saguinus, sqrt, many, recitative, michelob,
# Nearest to 'be': been, have, were, by, is, are, was, being,
# Nearest to 'when': if, but, while, until, iit, after, as, where,
# Nearest to 'after': before, during, when, at, building, durango, obelix, as,
# Nearest to 'called': and, mini, callithrix, waveforms, pontificia, considered, aba, hypertext,
# Nearest to 'system': prism, systems, dejima, kyushu, mitral, iit, hebrides, hydrophobic,
# Nearest to 'th': six, seven, three, eight, crusading, unemployment, blooms, spp,
# Nearest to 'no': a, weapons, herr, mitral, ayyavazhi, replayed, handshake, prestigious,
# Nearest to 'by': be, was, with, as, polyhedra, against, been, from,
# Nearest to 'its': their, his, the, her, tamias, some, dipyramid, asu,
# Nearest to 'not': often, also, it, they, still, never, you, always,
# Nearest to 'which': that, this, but, also, it, thibetanus, wct, and,
# Nearest to 'than': or, akh, much, valuable, disobeyed, cpl, ecclesiastical, rw,
# Nearest to 'to': cebus, would, rooks, marmoset, cuauht, nine, through, not,
# Nearest to 'that': which, this, however, but, iit, tangle, controlling, microcebus,
# Nearest to 'on': in, at, upon, from, under, trinomial, thaler, around,
# Average loss at step  92000 :  4.68189251208
# Average loss at step  94000 :  4.69300936913
# Average loss at step  96000 :  4.6640625515
# Average loss at step  98000 :  4.55110901022

# %% [markdown]
# -----
# Step 6: Visualize the embeddings.
# ----
#
# We'll use t-sne.
#
# [t-sne](https://lvdmaaten.github.io/tsne/) is a cool way to visualize of high-dimensional datasets by reducing the number dimensions.

# %%
tsne = TSNE(perplexity=30, 
            n_components=2, 
            init='pca', 
            n_iter=5000)
plot_only = 500
low_dim_embs = tsne.fit_transform(final_embeddings[:plot_only,:])
labels = [reverse_dictionary[i] for i in range(plot_only)]

n_words_to_visualize = 40

for i, label in enumerate(labels[:n_words_to_visualize]):
        x, y = low_dim_embs[i,:]
        plt.scatter(x, y)
        plt.annotate(label,
                     xy=(x, y),
                     xytext=(5, 2),
                     textcoords='offset points',
                     ha='right',
                     va='bottom')

# %% [markdown]
# ----
# Reflective Questions
# ----
#
# What do you see?
#
# How would you describe the relationships?

# %% [markdown]
# ------
#
# Let's render and save more samples.

# %%
def plot_with_labels(low_dim_embs, labels, filename='tsne.png'):
    assert low_dim_embs.shape[0] >= len(labels), "More labels than embeddings"
    plt.figure(figsize=(18, 18))  #in inches
    for i, label in enumerate(labels):
        x, y = low_dim_embs[i,:]
        plt.scatter(x, y)
        plt.annotate(label,
                     xy=(x, y),
                     xytext=(5, 2),
                     textcoords='offset points',
                     ha='right',
                     va='bottom')

    plt.savefig(filename)

# %%
tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000)
plot_only = 500
low_dim_embs = tsne.fit_transform(final_embeddings[:plot_only,:])
labels = [reverse_dictionary[i] for i in range(plot_only)]
plot_with_labels(low_dim_embs, labels)

# %% [markdown]
# <br>
# <br>
# <br>
#
# ----
