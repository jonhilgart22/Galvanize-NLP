# %% [markdown]
# 7.1 Exercise: Implementing CKY
# =====

# %% [markdown]
# Introduction
# -----
#
# For this project, you will build a probabilistic parser by implementing the CKY parser. We will be using the Manually Annotated Sub-Corpus (MASC) from the American National Corpus (ANC). Starter code and data are provided in `7_1_Exercise_Code_CKY`

# %% [markdown]
# Code
# ----
#
# At the beginning of the main method in `PCFGParserTester.py` some and test trees are read in. Currently, the training trees are used to construct a baseline parser (aptly named `BaselineParser`) that implements the `Parser` interface (which only has two methods: `train` and `get_best_parse`. The parser is then used to predict trees for the sentences in the test set. For each test sentence the parse given by your parser is evaluated by comparing the constituents it generates with the constituents in the hand-parsed version. From this, precision, recall, and the $F_1$ score are calculated.
#
# This baseline parser is really quite poor -- it takes a sentence, tags each word with its most likely tag (*i.e.*, a unigram tagger), then looks for occurrences of the tag sequence in the training set. If it finds an exact match, it answers with the training parse of the matching training sentence. If no match is found, it constructs a right-branching tree, with nodes’ labels chosen independently, conditioned only on the length of the span of a node. If this sounds like a strange (and terrible) way to parse, it should, and you’re going to provide a better solution.
#
# At the beginning of the main method in `PCFGParserTester.py` some and test trees are read in. Currently, the training trees are used to construct a baseline parser (aptly named `BaselineParser`) that implements the `Parser` interface (which only has two methods: `train` and `get_best_parse`. The parser is then used to predict trees for the sentences in the test set. For each test sentence the parse given by your parser is evaluated by comparing the constituents it generates with the constituents in the hand-parsed version. From this, precision, recall, and the $F_1$ score are calculated.
#
# This baseline parser is really quite poor -- it takes a sentence, tags each word with its most likely tag (*i.e.*, a unigram tagger), then looks for occurrences of the tag sequence in the training set. If it finds an exact match, it answers with the training parse of the matching training sentence. If no match is found, it constructs a right-branching tree, with nodes’ labels chosen independently, conditioned only on the length of the span of a node. If this sounds like a strange (and terrible) way to parse, it should, and you’re going to provide a better solution.
#
# You should familiarize yourself with these basic classes:
#
# - `ling.Tree`: CFG tree structures (pretty-print with `ling.Trees.PennTreeRenderer`)
# - `Lexicon`: Pre-terminal productions and probabilities
# - `Grammar`, `UnaryRule`, `BinaryRule`: CFG rules and accessors
#
# (For those wondering about `ling.Trees.PennTreeRenderer`, we will not be reading in Penn Treebank data but this Renderer is a good format for displaying any trees, the MASC included.) `Tree` is a linguistic tree class that you will use no matter what kind of parser you implement. `Lexicon` is a minimal lexicon, but it handles rare and unknown words adequately for the present purposes. You can use it to determine the pre-terminal productions for your parser if you like. Grammar is a class you can use to learn a PCFG from the training trees. Since the training set is hand-parsed this learning is very easy. We simply set $$\hat{P}(N^j\rightarrow\zeta)=\frac{C(N^j\rightarrow\zeta)}{\sum_\gamma C(N^j\rightarrow\gamma)}$$ where $C(N^j\rightarrow\gamma)$ is the count observed for that production in the data set. While you could consider smoothing rule rewrite probabilities, it is sufficient for this assignment to just work with unsmoothed MLE probabilities for rules. (Doing anything else makes things rather more complex and slow, since every rewrite will have a nonzero probability, so you should definitely get things working with an unsmoothed grammar before considering adding smoothing!)
#
# `UnaryRule` and `BinaryRule` are simply the classes the grammar uses to store these learned productions. They each bear the frequency estimated probabilities from the training set. Although it is not required, we strongly recommend that you get your parser working on the miniTest dataset before you attempt the treebank datasets. The `miniTest` data set consists of 3 training sentences and 1 test sentence from a toy grammar. There are just enough productions in the training set for the test sentence to have an ambiguity due to PP-attachment. There are unary, binary, and ternary grammar rules in training sentences.
#
# As discussed in the lecture videos, most parsers require grammars in which the rules are at most binary branching. You can binarize and unbinarize trees using the `TreeAnnotations` class. The implementation we give you binarizes the trees in a way that doesn't generalize the grammar at all. You should run some trees through the binarization process to get the idea of what's going on. If you annotate/binarize the training trees, you should be able to construct a Grammar out of them using the constructor provided.

# %% [markdown]
# Running the Code
# -----
#
# Make sure you can run the main method of the `PCFGParserTester` class. You can either run it from the data directory, or pass that directory in as the `--path` value. Use the `--data` value to specify which dataset to use (`miniTest` or `masc`). Running:

# %%
# %cd 7_1_Exercise_Code_CKY/python/
! python PCFGParserTester.py --path ../data/ --data miniTest
# Out:
# [Errno 2] No such file or directory: '7_1_Exercise_Code_CKY/python/'
# /Users/brian/github/DSCI6004-instructor/week7/7_1_ParsingAdv/7_1_Exercise_Code_CKY/python
# PCFGParserTest options:
#   path        : ../data/
#   test_data   :
#   max_length  : 20
#   parser      : BaselineParser
#   data        : miniTest
#
# Using parser: BaselineParser
# Data will be loaded from: ../data/
# Loading training trees...
# done.
# Loading test trees...
# done.
#
# Training parser...
# Testing parser
# Guess:
# (ROOT
#   (S
#     (NP (N cats))
#     (VP (V scratch)
#       (NP
#         (NP (N walls))
#         (PP (P with)
#           (NP (N claws)))))))
#
# Gold:
# (ROOT
#   (S
#     (NP (N cats))
#     (VP (V scratch)
#       (NP (N walls))
#       (PP (P with)
#         (NP (N claws))))))
#
#  [Current]    P: 85.71   R: 100.00   F1: 92.31   EX:  0.00
#
#  [Average]    P: 85.71   R: 100.00   F1: 92.31   EX:  0.00

# %% [markdown]
# from the `python/` directory will train and test your parser on a few sentences from a toy grammar.
#
# Train and test your parser on the MASC dataset by running:

# %%
! python PCFGParserTester.py --path ../data/ --data masc
# Out:
# PCFGParserTest options:
#   path        : ../data/
#   test_data   :
#   max_length  : 20
#   parser      : BaselineParser
#   data        : masc
#
# Using parser: BaselineParser
# Data will be loaded from: ../data/
# Loading MASC training trees... from: ../data/parser/masc/train
# Reading MASC from ../data/parser/masc/train
# done.
# Train trees size: 3595
# First train tree: (ROOT
#   (NP (NNP December) (CD 1998)))
#
# Last train tree: (ROOT
#   (S
#     (NP
#       (NP (DT The) (NNPS Soviets) (POS '))
#       (NN eavesdropping))
#     (VP (VBD paid)
#       (PRT (RP off))
#       (, ,)
#       (ADVP (RB however))
#       (, ,)
#       (SBAR (IN because)
#         (S
#           (NP (PRP they))
#           (VP (VBD got)
#             (NP (DT the) (NN contract))))))
#     (. .)))
#
# Loading MASC test trees...
# Reading MASC from ../data/parser/masc/devtest
# done.
# Test trees size: 355
# First test tree: (ROOT
#   (NP
#     (NP (NNP August) (CD 4))
#     (, ,)
#     (NP (CD 1999))))
#
# Last test tree: (ROOT
#   (S
#     (NP (NNP Tara))
#     (VP (MD would) (RB not)
#       (VP (VB let)
#         (S
#           (NP (JJ giddy) (NNS hopes))
#           (VP (VB drag)
#             (NP (PRP them))
#             (PP (IN onto)
#               (NP
#                 (NP (DT a) (NN rock))
#                 (SBAR
#                   (WHNP (WDT that))
#                   (S
#                     (VP (MD would)
#                       (VP (VB spell)
#                         (NP (DT the) (NN end))
#                         (PP (IN for)
#                           (NP
#                             (NP (DT the) (NN project))
#                             (, ,)
#                             (CC and)
#                             (NP (DT the) (NNP Arrallin) (NN species))))))))))))))
#     (. .)))
#
#
# Training parser...
# Testing parser
# Guess:
# (ROOT
#   (NP
#     (NP (NNP August) (CD 4))
#     (, ,)
#     (NP (CD 1999))))
#
# Gold:
# (ROOT
#   (NP
#     (NP (NNP August) (CD 4))
#     (, ,)
#     (NP (CD 1999))))
#
#  [Current]    P: 100.00   R: 100.00   F1: 100.00   EX: 100.00
# Guess:
# (ROOT
#   (VP (NNP Name)
#     (NP (NN Address)
#       (NP (NNP City)
#         (NP (, ,)
#           (NP (NN ST) (NN Zip)))))))
#
# Gold:
# (ROOT
#   (NP
#     (NP (NN Name))
#     (NP (NN Address))
#     (NP (NN City))
#     (, ,)
#     (NP (NN ST))
#     (NP (NN Zip))))
#
#  [Current]    P:  0.00   R:  0.00   F1:  0.00   EX:  0.00
# Guess:
# (ROOT
#   (VP (DT The)
#     (VP (NN goal)
#       (VP (IN of)
#         (VP (LS MCCOY)
#           (VP (, ,)
#             (VP (NNP Inc.)
#               (VP (VBZ has)
#                 (VP (VBN been)
#                   (NP (TO to)
#                     (NP (VB make)
#                       (NP (DT a)
#                         (NP (NN difference) (. .))))))))))))))
#
# Gold:
# (ROOT
#   (S
#     (NP
#       (NP (DT The) (NN goal))
#       (PP (IN of)
#         (NP (NNP MCCOY) (, ,) (NNP Inc.))))
#     (VP (VBZ has)
#       (VP (VBN been)
#         (S
#           (VP (TO to)
#             (VP (VB make)
#               (NP (DT a) (NN difference)))))))
#     (. .)))
#
#  [Current]    P: 27.27   R: 27.27   F1: 27.27   EX:  0.00
# Guess:
# (ROOT
#   (VP (DT That)
#     (NP (VBP need)
#       (NP (VBZ is)
#         (NP (VBG being)
#           (NP (VBD met) (. .)))))))
#
# Gold:
# (ROOT
#   (S
#     (NP (DT That) (NN need))
#     (VP (VBZ is)
#       (VP (VBG being)
#         (VP (VBN met))))
#     (. .)))
#
#  [Current]    P:  0.00   R:  0.00   F1:  0.00   EX:  0.00
# Guess:
# (ROOT
#   (VP (RB Sincerely)
#     (VP (, ,)
#       (VP (NNP John)
#         (VP (NNP F.)
#           (VP (LS Brandon)
#             (NP (, ,)
#               (NP (NNP President)
#                 (NP (LS MCCOY)
#                   (NP (, ,) (NNP Inc.)))))))))))
#
# Gold:
# (ROOT
#   (FRAG
#     (ADVP (RB Sincerely))
#     (, ,)
#     (NP
#       (NP (NNP John) (NNP F.) (NNP Brandon))
#       (, ,)
#       (NP
#         (NP (NNP President))
#         (NP (NNP MCCOY) (, ,) (NNP Inc.))))))
#
#  [Current]    P: 28.57   R: 28.57   F1: 28.57   EX:  0.00
# Guess:
# (ROOT
#   (NP
#     (NP (NNP January) (CD 5))
#     (, ,)
#     (NP (CD 1997))))
#
# Gold:
# (ROOT
#   (NP
#     (NP (NNP January) (CD 5))
#     (, ,)
#     (NP (CD 1997))))
#
#  [Current]    P: 100.00   R: 100.00   F1: 100.00   EX: 100.00
# Guess:
# (ROOT
#   (VP (NNP Name)
#     (NP (NN Address)
#       (NP (NNP City)
#         (NP (, ,)
#           (NP (NN ST) (NN Zip)))))))
#
# Gold:
# (ROOT
#   (NP
#     (NP (NN Name))
#     (NP (NN Address))
#     (NP (NN City))
#     (, ,)
#     (NP (NN ST))
#     (NP (NN Zip))))
#
#  [Current]    P:  0.00   R:  0.00   F1:  0.00   EX:  0.00
# Guess:
# (ROOT
#   (NP (JJ Dear)
#     (NP (NNP Bill) (: :))))
#
# Gold:
# (ROOT
#   (NP (JJ Dear) (NNP Bill) (: :)))
#
#  [Current]    P: 50.00   R: 100.00   F1: 66.67   EX:  0.00
# Guess:
# (ROOT
#   (VP (PRP I)
#     (VP (MD will)
#       (VP (VB call)
#         (VP (PRP you)
#           (VP (IN in)
#             (VP (DT a)
#               (VP (JJ few)
#                 (VP (NNS weeks)
#                   (VP (TO to)
#                     (VP (VB discuss)
#                       (NP (PRP$ your)
#                         (NP (NN level)
#                           (NP (IN of)
#                             (NP (NN interest) (. .))))))))))))))))
#
# Gold:
# (ROOT
#   (S
#     (NP (PRP I))
#     (VP (MD will)
#       (VP (VB call)
#         (NP (PRP you))
#         (PP (IN in)
#           (NP (DT a) (JJ few) (NNS weeks)))
#         (S
#           (VP (TO to)
#             (VP (VB discuss)
#               (NP
#                 (NP (PRP$ your) (NN level))
#                 (PP (IN of)
#                   (NP (NN interest)))))))))
#     (. .)))
#
#  [Current]    P: 42.86   R: 42.86   F1: 42.86   EX:  0.00
# Guess:
# (ROOT
#   (VP (RB Sincerely)
#     (NP (, ,)
#       (NP (NNP John)
#         (NP (LS Brandon)
#           (NP (NNP Executive) (NNP Director)))))))
#
# Gold:
# (ROOT
#   (FRAG
#     (ADVP (RB Sincerely))
#     (, ,)
#     (NP
#       (NP (NNP John) (NNP Brandon))
#       (NP (NNP Executive) (NNP Director)))))
#
#  [Current]    P: 50.00   R: 40.00   F1: 44.44   EX:  0.00
# Guess:
# (ROOT
#   (NP
#     (NP (NNP October) (CD 7))
#     (, ,)
#     (NP (CD 1996))))
#
# Gold:
# (ROOT
#   (NP
#     (NP (NNP October) (CD 7))
#     (, ,)
#     (NP (CD 1996))))
#
#  [Current]    P: 100.00   R: 100.00   F1: 100.00   EX: 100.00
# Guess:
# (ROOT
#   (VP (NNP Name)
#     (NP (NN Address)
#       (NP (NNP City)
#         (NP (, ,)
#           (NP (NN ST) (NN Zip)))))))
#
# Gold:
# (ROOT
#   (NP
#     (NP (NN Name))
#     (NP (NN Address))
#     (NP (NN City))
#     (, ,)
#     (NP (NN ST))
#     (NP (NN Zip))))
#
#  [Current]    P:  0.00   R:  0.00   F1:  0.00   EX:  0.00
# Guess:
# (ROOT
#   (NP (JJ Dear)
#     (NP (NNP Name) (: :))))
#
# Gold:
# (ROOT
#   (NP (JJ Dear) (NNP Name) (. :)))
#
#  [Current]    P: 50.00   R: 100.00   F1: 66.67   EX:  0.00
# Guess:
# (ROOT
#   (VP (LS MCCOY)
#     (VP (VBD was)
#       (VP (LS reorganized)
#         (VP (IN as)
#           (VP (DT an)
#             (VP (JJ independent)
#               (VP (, ,)
#                 (VP (JJ not-for-profit)
#                   (VP (NN agency)
#                     (VP (, ,)
#                       (NP (JJ separate)
#                         (NP (IN from)
#                           (NP (JJ local)
#                             (NP (NN government) (. .))))))))))))))))
#
# Gold:
# (ROOT
#   (S
#     (NP (NNP MCCOY))
#     (VP (VBD was)
#       (VP (VBN reorganized)
#         (PP (IN as)
#           (NP
#             (NP (DT an) (JJ independent) (, ,) (JJ not-for-profit) (NN agency))
#             (, ,)
#             (ADJP (JJ separate)
#               (PP (IN from)
#                 (NP (JJ local) (NN government))))))))
#     (. .)))
#
#  [Current]    P: 23.08   R: 30.00   F1: 26.09   EX:  0.00
# Guess:
# (ROOT
#   (VP (LS McCoy)
#     (VP (VBZ has)
#       (VP (RB only)
#         (VP (CD one)
#           (VP (NN interest)
#             (VP (: :)
#               (VP (DT the)
#                 (VP (RB well)
#                   (VP (VBG being)
#                     (VP (IN of)
#                       (VP (NNP Marion)
#                         (NP (NNP County)
#                           (NP (POS 's)
#                             (NP (JJ young)
#                               (NP (NNS people) (. .)))))))))))))))))
#
# Gold:
# (ROOT
#   (S
#     (NP (NNP McCoy))
#     (VP (VBZ has)
#       (NP
#         (NP
#           (QP (RB only) (CD one))
#           (NN interest))
#         (: :)
#         (NP
#           (NP (DT the) (NN well) (NN being))
#           (PP (IN of)
#             (NP
#               (NP (NNP Marion) (NNP County) (POS 's))
#               (JJ young) (NNS people))))))
#     (. .)))
#
#  [Current]    P:  7.14   R:  9.09   F1:  8.00   EX:  0.00
# Guess:
# (ROOT
#   (NP
#     (NP (NNP July) (CD 28))
#     (, ,)
#     (NP (CD 1999))))
#
# Gold:
# (ROOT
#   (NP
#     (NP (NNP July) (CD 28))
#     (, ,)
#     (NP (CD 1999))))
#
#  [Current]    P: 100.00   R: 100.00   F1: 100.00   EX: 100.00
# Guess:
# (ROOT (JJ Dear))
#
# Gold:
# (ROOT
#   (NP (JJ Dear)))
#
#  [Current]    P: 100.00   R:  0.00   F1:  0.00   EX:  0.00
# Guess:
# (ROOT
#   (VP (DT The)
#     (VP (LS JCC)
#       (VP (MD would)
#         (VP (VB be)
#           (VP (RB very)
#             (VP (JJ pleased)
#               (VP (TO to)
#                 (VP (VBP welcome)
#                   (VP (PRP$ your)
#                     (VP (NN organization)
#                       (NP (IN as)
#                         (NP (DT a)
#                           (NP (JJ corporate)
#                             (NP (FW sponsor) (. .))))))))))))))))
#
# Gold:
# (ROOT
#   (S
#     (NP (DT The) (NNP JCC))
#     (VP (MD would)
#       (VP (VB be)
#         (ADJP (RB very) (JJ pleased)
#           (S
#             (VP (TO to)
#               (VP (VB welcome)
#                 (NP (PRP$ your) (NN organization))
#                 (PP (IN as)
#                   (NP (DT a) (JJ corporate) (NN sponsor)))))))))
#     (. .)))
#
#  [Current]    P: 35.71   R: 45.45   F1: 40.00   EX:  0.00
# Guess:
# (ROOT
#   (VP (PRP We)
#     (VP (VBP are)
#       (VP (VBG seeking)
#         (VP (TO to)
#           (VP (VB build)
#             (VP (LS partnerships)
#               (VP (IN between)
#                 (VP (NNS businesses)
#                   (NP (CC and)
#                     (NP (PRP$ our)
#                       (NP (JJ not-for-profit)
#                         (NP (NN agency) (. .))))))))))))))
#
# Gold:
# (ROOT
#   (S
#     (NP (PRP We))
#     (VP (VBP are)
#       (VP (VBG seeking)
#         (S
#           (VP (TO to)
#             (VP (VB build)
#               (NP
#                 (NP (NNS partnerships))
#                 (PP (IN between)
#                   (NP
#                     (NP (NNS businesses))
#                     (CC and)
#                     (NP (PRP$ our) (JJ not-for-profit) (NN agency))))))))))
#     (. .)))
#
#  [Current]    P: 41.67   R: 38.46   F1: 40.00   EX:  0.00
# Guess:
# (ROOT
#   (S (IN If)
#     (VP (PRP you)
#       (S (VBP have)
#         (VP (DT any)
#           (VP (NNS questions)
#             (VP (, ,)
#               (VP (UH please)
#                 (VP (VBP feel)
#                   (VP (JJ free)
#                     (VP (TO to)
#                       (VP (VB call)
#                         (VP (LS Myrna)
#                           (VP (LS Weinberger)
#                             (VP (IN at)
#                               (NP (LS 251-9467)
#                                 (NP (, ,)
#                                   (NP (NN ext.)
#                                     (NP (LS 256) (. .))))))))))))))))))))
#
# Gold:
# (ROOT
#   (S
#     (SBAR (IN If)
#       (S
#         (NP (PRP you))
#         (VP (VBP have)
#           (NP (DT any) (NNS questions)))))
#     (, ,)
#     (INTJ (UH please))
#     (VP (VB feel)
#       (ADJP (JJ free)
#         (S
#           (VP (TO to)
#             (VP (VB call)
#               (NP (NNP Myrna) (NNP Weinberger))
#               (PP (IN at)
#                 (NP
#                   (NP (CD 251-9467))
#                   (, ,)
#                   (NP (NN ext.) (CD 256)))))))))
#     (. .)))
#
#  [Current]    P: 37.50   R: 35.29   F1: 36.36   EX:  0.00
# Guess:
# (ROOT
#   (VP (VBP Thank)
#     (VP (PRP you)
#       (VP (IN in)
#         (NP (NN advance)
#           (NP (IN for)
#             (NP (PRP$ your)
#               (NP (NN consideration) (. .)))))))))
#
# Gold:
# (ROOT
#   (S
#     (VP (VBP Thank)
#       (NP (PRP you))
#       (PP (IN in)
#         (NP (NN advance)))
#       (PP (IN for)
#         (NP (PRP$ your) (NN consideration))))
#     (. .)))
#
#  [Current]    P: 28.57   R: 28.57   F1: 28.57   EX:  0.00
# Guess:
# (ROOT
#   (VP (RB Sincerely)
#     (VP (, ,)
#       (VP (LS Judy)
#         (VP (LS Laikin)
#           (VP (, ,)
#             (NP (NNP Chair)
#               (NP (LS Auction)
#                 (NP (LS '99)
#                   (NP (VB Sponsor) (NNP Committee)))))))))))
#
# Gold:
# (ROOT
#   (FRAG
#     (ADVP (RB Sincerely))
#     (, ,)
#     (NP
#       (NP (NNP Judy) (NNP Laikin))
#       (, ,)
#       (NP
#         (NP (NNP Chair) (NNP Auction))
#         (NP (NNP '99) (NNP Sponsor) (NNP Committee))))))
#
#  [Current]    P: 25.00   R: 28.57   F1: 26.67   EX:  0.00
# Guess:
# (ROOT
#   (NP
#     (NP (NNP October) (CD 27))
#     (, ,)
#     (NP (CD 1998))))
#
# Gold:
# (ROOT
#   (NP
#     (NP (NNP October) (CD 27))
#     (, ,)
#     (NP (CD 1998))))
#
#  [Current]    P: 100.00   R: 100.00   F1: 100.00   EX: 100.00
# Guess:
# (ROOT
#   (NP (JJ Dear)
#     (NP (NNP Name) (: :))))
#
# Gold:
# (ROOT
#   (NP (JJ Dear) (NN Name) (. :)))
#
#  [Current]    P: 50.00   R: 100.00   F1: 66.67   EX:  0.00
# Guess:
# (ROOT
#   (VP (PRP We)
#     (VP (VBP are)
#       (VP (RB so)
#         (VP (LS grateful)
#           (VP (IN for)
#             (VP (PRP$ your)
#               (VP (JJ generous)
#                 (VP (NN contribution)
#                   (VP (TO to)
#                     (NP (JJ last)
#                       (NP (NN year)
#                         (NP (POS 's)
#                           (NP (LS auction) (. .)))))))))))))))
#
# Gold:
# (ROOT
#   (S
#     (NP (PRP We))
#     (VP (VBP are)
#       (ADJP (RB so) (JJ grateful)
#         (PP (IN for)
#           (NP
#             (NP (PRP$ your) (JJ generous) (NN contribution))
#             (PP (TO to)
#               (NP
#                 (NP (JJ last) (NN year) (POS 's))
#                 (NN auction)))))))
#     (. .)))
#
#  [Current]    P: 15.38   R: 20.00   F1: 17.39   EX:  0.00
# Guess:
# (ROOT
#   (S (IN If)
#     (VP (PRP you)
#       (S (VBP have)
#         (VP (DT any)
#           (VP (NNS questions)
#             (VP (, ,)
#               (VP (UH please)
#                 (VP (VBP feel)
#                   (VP (JJ free)
#                     (VP (TO to)
#                       (VP (VB call)
#                         (VP (LS Myrna)
#                           (VP (LS Weinberger)
#                             (VP (IN at)
#                               (NP (LS 251-9467)
#                                 (NP (, ,)
#                                   (NP (NN ext.)
#                                     (NP (LS 256) (. .))))))))))))))))))))
#
# Gold:
# (ROOT
#   (S
#     (SBAR (IN If)
#       (S
#         (NP (PRP you))
#         (VP (VBP have)
#           (NP (DT any) (NNS questions)))))
#     (, ,)
#     (INTJ (UH please))
#     (VP (VB feel)
#       (ADJP (JJ free)
#         (S
#           (VP (TO to)
#             (VP (VB call)
#               (NP (NNP Myrna) (NNP Weinberger))
#               (PP (IN at)
#                 (NP
#                   (NP (CD 251-9467))
#                   (, ,)
#                   (NP (NN ext.) (CD 256)))))))))
#     (. .)))
#
#  [Current]    P: 37.50   R: 35.29   F1: 36.36   EX:  0.00
# Guess:
# (ROOT
#   (VP (VBP Thank)
#     (VP (PRP you)
#       (VP (IN in)
#         (NP (NN advance)
#           (NP (IN for)
#             (NP (PRP$ your)
#               (NP (NN consideration) (. .)))))))))
#
# Gold:
# (ROOT
#   (S
#     (VP (VBP Thank)
#       (NP (PRP you))
#       (PP (IN in)
#         (NP (NN advance)))
#       (PP (IN for)
#         (NP (PRP$ your) (NN consideration))))
#     (. .)))
#
#  [Current]    P: 28.57   R: 28.57   F1: 28.57   EX:  0.00
# Guess:
# (ROOT
#   (VP (RB Sincerely)
#     (VP (, ,)
#       (VP (LS Judy)
#         (VP (LS Laikin)
#           (VP (, ,)
#             (NP (NNP Chair)
#               (NP (LS Auction)
#                 (NP (LS '99)
#                   (NP (VB Sponsor) (NNP Committee)))))))))))
#
# Gold:
# (ROOT
#   (FRAG
#     (ADVP (RB Sincerely))
#     (, ,)
#     (NP
#       (NP (NNP Judy) (NNP Laikin))
#       (, ,)
#       (NP
#         (NP (NNP Chair))
#         (NP
#           (NML (NNP Auction) (NNP '99))
#           (NNP Sponsor) (NNP Committee))))))
#
#  [Current]    P: 25.00   R: 25.00   F1: 25.00   EX:  0.00
# Guess:
# (ROOT
#   (NP (NNP IRAQ)
#     (NP (HYPH -) (LS POVERTY))))
#
# Gold:
# (ROOT
#   (NP (NNP IRAQ) (HYPH -) (NN POVERTY)))
#
#  [Current]    P: 50.00   R: 100.00   F1: 66.67   EX:  0.00
# Guess:
# (ROOT
#   (NP (-LRB- -LRB-)
#     (NP (NNP Washington) (-RRB- -RRB-))))
#
# Gold:
# (ROOT
#   (NP (-LRB- -LRB-) (NNP Washington) (-RRB- -RRB-)))
#
#  [Current]    P: 50.00   R: 100.00   F1: 66.67   EX:  0.00
# Guess:
# (ROOT
#   (NP (IN By)
#     (NP (LS AUSTIN)
#       (NP (LS ZALKIN) (. .)))))
#
# Gold:
# (ROOT
#   (PP (IN By)
#     (NP (NNP AUSTIN) (NNP ZALKIN))
#     (. .)))
#
#  [Current]    P: 33.33   R: 50.00   F1: 40.00   EX:  0.00
# Guess:
# (ROOT
#   (VP (NNP Iraq)
#     (VP (LS Lodges)
#       (VP (LS Protest)
#         (VP (IN with)
#           (VP (NNP United)
#             (VP (LS Nations)
#               (NP (LS Concerning)
#                 (NP (NNPS British)
#                   (NP (CC and)
#                     (NP (JJ American) (LS Raids))))))))))))
#
# Gold:
# (ROOT
#   (S
#     (NP (NNP Iraq))
#     (VP (VBZ Lodges)
#       (NP (NN Protest))
#       (PP (IN with)
#         (NP (NNP United) (NNP Nations)))
#       (PP (IN Concerning)
#         (NP
#           (ADJP (JJ British)
#             (CC and)
#             (JJ American))
#           (NNS Raids))))))
#
#  [Current]    P: 20.00   R: 22.22   F1: 21.05   EX:  0.00
# Guess:
# (ROOT
#   (VP (NNP Baghdad)
#     (VP (CD 8)
#       (VP (HYPH -)
#         (NP (CD 15)
#           (NP (-LRB- -LRB-)
#             (NP (NNP AFP)
#               (NP (-RRB- -RRB-) (HYPH -)))))))))
#
# Gold:
# (ROOT
#   (FRAG
#     (NP (NNP Baghdad))
#     (NP (CD 8) (HYPH -) (CD 15))
#     (-LRB- -LRB-)
#     (NP (NNP AFP))
#     (-RRB- -RRB-) (. -)))
#
#  [Current]    P:  0.00   R:  0.00   F1:  0.00   EX:  0.00
# Guess:
# (ROOT
#   (VP (NNP Baghdad)
#     (VP (VBZ does)
#       (VP (RB not)
#         (VP (VBP recognize)
#           (VP (DT these)
#             (VP (LS no-fly)
#               (VP (NNS zones)
#                 (VP (IN for)
#                   (VP (WDT which)
#                     (VP (UH no)
#                       (VP (JJ international)
#                         (NP (NN resolution)
#                           (NP (VBZ has)
#                             (NP (VBN been)
#                               (NP (VBD passed) (. .)))))))))))))))))
#
# Gold:
# (ROOT
#   (S
#     (NP (NNP Baghdad))
#     (VP (VBZ does) (RB not)
#       (VP (VB recognize)
#         (NP
#           (NP (DT these) (JJ no-fly) (NNS zones))
#           (SBAR
#             (WHPP (IN for)
#               (WHNP (WDT which)))
#             (S
#               (NP (DT no) (JJ international) (NN resolution))
#               (VP (VBZ has)
#                 (VP (VBN been)
#                   (VP (VBN passed)))))))))
#     (. .)))
#
#  [Current]    P: 13.33   R: 14.29   F1: 13.79   EX:  0.00
# Guess:
# (ROOT
#   (VP (DT The)
#     (NP (LS Entrepreneur)
#       (NP (VBZ Is)
#         (NP (DT the)
#           (NP (NNP New) (LS Madonna)))))))
#
# Gold:
# (ROOT
#   (S
#     (NP (DT The) (NN Entrepreneur))
#     (VP (VBZ Is)
#       (NP (DT the) (JJ New) (NNP Madonna)))))
#
#  [Current]    P: 20.00   R: 25.00   F1: 22.22   EX:  0.00
# Guess:
# (ROOT
#   (VP (JJ Dear)
#     (VP (NNP Joe)
#       (VP (, ,)
#         (VP (PRP I)
#           (VP (VBP know)
#             (VP (WP what)
#               (VP (PRP you)
#                 (VP (VBP mean)
#                   (NP (IN about)
#                     (NP (VBG being)
#                       (NP (DT a)
#                         (NP (NN journalist) (. .))))))))))))))
#
# Gold:
# (ROOT
#   (S
#     (NP (JJ Dear) (NNP Joe))
#     (, ,)
#     (NP (PRP I))
#     (VP (VBP know)
#       (SBAR
#         (WHNP (WP what))
#         (S
#           (NP (PRP you))
#           (VP (VBP mean)
#             (PP (IN about)
#               (S
#                 (VP (VBG being)
#                   (NP (DT a) (NN journalist)))))))))
#     (. .)))
#
#  [Current]    P: 27.27   R: 23.08   F1: 25.00   EX:  0.00
# Guess:
# (ROOT
#   (VP (LS Almost)
#     (S (DT every)
#       (VP (LS assignment)
#         (VP (VBZ is)
#           (VP (DT a)
#             (VP (NN challenge)
#               (VP (IN in)
#                 (VP (DT a)
#                   (VP (JJ different)
#                     (VP (NN way)
#                       (VP (CC and)
#                         (VP (PRP it)
#                           (VP (RB never)
#                             (NP (VBZ seems)
#                               (NP (TO to)
#                                 (NP (VB get)
#                                   (NP (LS easier) (. .)))))))))))))))))))
#
# Gold:
# (ROOT
#   (S
#     (S
#       (NP (RB Almost) (DT every) (NN assignment))
#       (VP (VBZ is)
#         (NP
#           (NP (DT a) (NN challenge))
#           (PP (IN in)
#             (NP (DT a) (JJ different) (NN way))))))
#     (CC and)
#     (S
#       (NP (PRP it))
#       (ADVP (RB never))
#       (VP (VBZ seems)
#         (S
#           (VP (TO to)
#             (VP (VB get)
#               (ADJP (JJR easier)))))))
#     (. .)))
#
#  [Current]    P:  0.00   R:  0.00   F1:  0.00   EX:  0.00
# Guess:
# (ROOT
#   (VP (VB Think)
#     (S (IN of)
#       (VP (PDT all)
#         (S (DT the)
#           (VP (JJ good)
#             (VP (NN stuff)
#               (VP (PRP we)
#                 (VP (PDT all)
#                   (VP (VB collect)
#                     (VP (JJ daily)
#                       (VP (IN in)
#                         (VP (PRP$ our)
#                           (VP (NN reporting)
#                             (VP (WDT that)
#                               (VP (PRP we)
#                                 (NP (RB never)
#                                   (NP (VB add)
#                                     (NP (TO to)
#                                       (NP (NNS stories) (. .)))))))))))))))))))))
#
# Gold:
# (ROOT
#   (S
#     (VP (VB Think)
#       (PP (IN of)
#         (NP
#           (NP
#             (NP (PDT all) (DT the) (JJ good) (NN stuff))
#             (SBAR
#               (S
#                 (NP
#                   (NP (PRP we))
#                   (NP (DT all)))
#                 (VP (VBP collect)
#                   (ADVP (RB daily))
#                   (PP (IN in)
#                     (NP (PRP$ our) (NN reporting)))))))
#           (SBAR
#             (WHNP (WDT that))
#             (S
#               (NP (PRP we))
#               (ADVP (RB never))
#               (VP (VBP add)
#                 (PP (TO to)
#                   (NP (NNS stories)))))))))
#     (. .)))
#
#  [Current]    P: 10.53   R:  8.70   F1:  9.52   EX:  0.00
# Guess:
# (ROOT
#   (VP (CC So)
#     (S (DT the)
#       (VP (LS shift)
#         (VP (IN in)
#           (VP (DT the)
#             (VP (NN image)
#               (VP (IN of)
#                 (VP (LS Gates)
#                   (VP (VBZ has)
#                     (VP (VBN been)
#                       (VP (DT an)
#                         (VP (JJ interesting)
#                           (VP (CD one)
#                             (NP (IN for)
#                               (NP (PRP me)
#                                 (NP (TO to)
#                                   (NP (VB watch) (. .)))))))))))))))))))
#
# Gold:
# (ROOT
#   (S (CC So)
#     (NP
#       (NP (DT the) (NN shift))
#       (PP (IN in)
#         (NP
#           (NP (DT the) (NN image))
#           (PP (IN of)
#             (NP (NNP Gates))))))
#     (VP (VBZ has)
#       (VP (VBN been)
#         (NP
#           (NP (DT an) (JJ interesting) (NN one))
#           (SBAR (IN for)
#             (S
#               (NP (PRP me))
#               (VP (TO to)
#                 (VP (VB watch))))))))
#     (. .)))
#
#  [Current]    P: 11.76   R: 11.76   F1: 11.76   EX:  0.00
# Guess:
# (ROOT
#   (VP (DT The)
#     (VP (JJ smart)
#       (VP (HYPH -)
#         (VP (NN boy)
#           (VP (NN technologist)
#             (VP (VBZ is)
#               (VP (RB now)
#                 (VP (VBG being)
#                   (VP (LS painted)
#                     (NP (IN as)
#                       (NP (DT the)
#                         (NP (LS whiny)
#                           (NP (LS bully) (. .)))))))))))))))
#
# Gold:
# (ROOT
#   (S
#     (NP (DT The)
#       (NML (JJ smart) (HYPH -) (NN boy))
#       (NN technologist))
#     (VP (VBZ is)
#       (ADVP (RB now))
#       (VP (VBG being)
#         (VP (VBN painted)
#           (PP (IN as)
#             (NP (DT the) (JJ whiny) (NN bully))))))
#     (. .)))
#
#  [Current]    P: 30.77   R: 44.44   F1: 36.36   EX:  0.00
# Guess:
# (ROOT
#   (S (RB Out)
#     (VP (IN in)
#       (S (DT the)
#         (VP (LS D.C.)
#           (VP (NN area)
#             (VP (, ,)
#               (VP (PRP they)
#                 (VP (VBD looked)
#                   (VP (LS positively)
#                     (VP (JJ exciting)
#                       (VP (JJ next)
#                         (VP (TO to)
#                           (VP (PDT all)
#                             (VP (DT the)
#                               (NP (NN government)
#                                 (NP (HYPH -)
#                                   (NP (VBN oriented)
#                                     (NP (LS contractors) (. .))))))))))))))))))))
#
# Gold:
# (ROOT
#   (S
#     (ADVP (RB Out)
#       (PP (IN in)
#         (NP (DT the) (NNP D.C.) (NN area))))
#     (, ,)
#     (NP (PRP they))
#     (VP (VBD looked)
#       (ADJP (RB positively) (JJ exciting))
#       (ADVP (RB next)
#         (PP (TO to)
#           (NP (PDT all) (DT the)
#             (ADJP (NN government) (HYPH -) (VBN oriented))
#             (NNS contractors)))))
#     (. .)))
#
#  [Current]    P: 11.76   R: 18.18   F1: 14.29   EX:  0.00
# Guess:
# (ROOT
#   (S (PRP I)
#     (VP (VB wonder)
#       (S (IN if)
#         (VP (WDT that)
#           (VP (VBZ means)
#             (VP (NN geography)
#               (VP (VBZ is)
#                 (VP (NN destiny)
#                   (VP (, ,)
#                     (VP (CC and)
#                       (VP (PRP it)
#                         (VP (POS 's)
#                           (VP (RB still)
#                             (VP (NN location)
#                               (NP (, ,)
#                                 (NP (NN location)
#                                   (NP (, ,)
#                                     (NP (NN location) (. .))))))))))))))))))))
#
# Gold:
# (ROOT
#   (S
#     (NP (PRP I))
#     (VP (VBP wonder)
#       (SBAR (IN if)
#         (S
#           (NP (DT that))
#           (VP (VBZ means)
#             (SBAR
#               (S
#                 (S
#                   (NP (NN geography))
#                   (VP (VBZ is)
#                     (NP (NN destiny))))
#                 (, ,)
#                 (CC and)
#                 (S
#                   (NP (PRP it))
#                   (VP (VBZ 's)
#                     (ADVP (RB still))
#                     (NP (NN location) (, ,) (NN location) (, ,) (NN location))))))))))
#     (. .)))
#
#  [Current]    P: 26.67   R: 22.22   F1: 24.24   EX:  0.00
# Guess:
# (ROOT
#   (VP (CC But)
#     (VP (PRP we)
#       (VP (PDT all)
#         (VP (VBP know)
#           (VP (WRB how)
#             (NP (WDT that)
#               (NP (NN story)
#                 (NP (VBD turned)
#                   (NP (RP out) (. .)))))))))))
#
# Gold:
# (ROOT
#   (S (CC But)
#     (NP
#       (NP (PRP we))
#       (NP (DT all)))
#     (VP (VBP know)
#       (SBAR
#         (WHADVP (WRB how))
#         (S
#           (NP (DT that) (NN story))
#           (VP (VBD turned)
#             (PRT (RP out))))))
#     (. .)))
#
#  [Current]    P: 11.11   R:  9.09   F1: 10.00   EX:  0.00
# Guess:
# (ROOT
#   (S (UH Now)
#     (VP (PRP I)
#       (S (VBP am)
#         (VP (VBG getting)
#           (VP (NN way)
#             (VP (RB too)
#               (VP (LS philosophical)
#                 (VP (, ,)
#                   (VP (CC but)
#                     (VP (DT this)
#                       (VP (VBZ is)
#                         (VP (PRP$ my)
#                           (VP (JJ final)
#                             (VP (LS missive)
#                               (NP (, ,)
#                                 (NP (RB so)
#                                   (NP (WRB why)
#                                     (NP (RB not) (. ?))))))))))))))))))))
#
# Gold:
# (ROOT
#   (S
#     (S
#       (ADVP (RB Now))
#       (NP (PRP I))
#       (VP (VBP am)
#         (VP (VBG getting)
#           (ADJP
#             (ADVP (RB way) (RB too))
#             (JJ philosophical)))))
#     (, ,)
#     (CC but)
#     (S
#       (S
#         (NP (DT this))
#         (VP (VBZ is)
#           (NP (PRP$ my) (JJ final) (JJ missive))))
#       (, ,)
#       (CC so)
#       (SBARQ
#         (WHADVP (WRB why))
#         (FRAG (RB not))))
#     (. ?)))
#
#  [Current]    P:  6.25   R:  6.25   F1:  6.25   EX:  0.00
# Guess:
# (ROOT
#   (VP (RB Perhaps)
#     (VP (PRP you)
#       (VP (MD could)
#         (VP (LS hasten)
#           (VP (DT a)
#             (VP (LS prediction)
#               (VP (IN of)
#                 (VP (WRB where)
#                   (NP (DT this)
#                     (NP (VBZ is)
#                       (NP (PDT all)
#                         (NP (VBG going) (. .))))))))))))))
#
# Gold:
# (ROOT
#   (S
#     (ADVP (RB Perhaps))
#     (NP (PRP you))
#     (VP (MD could)
#       (VP (VB hasten)
#         (NP
#           (NP (DT a) (NN prediction))
#           (PP (IN of)
#             (SBAR
#               (WHADVP (WRB where))
#               (S
#                 (NP (DT this))
#                 (VP (VBZ is) (DT all)
#                   (VP (VBG going)))))))))
#     (. .)))
#
#  [Current]    P: 16.67   R: 14.29   F1: 15.38   EX:  0.00
# Guess:
# (ROOT
#   (NP (LS Cheers)
#     (NP (, ,) (LS Kara))))
#
# Gold:
# (ROOT
#   (FRAG
#     (NP (NNS Cheers))
#     (, ,)
#     (NP (NNP Kara))))
#
#  [Current]    P: 50.00   R: 33.33   F1: 40.00   EX:  0.00
# Guess:
# (ROOT
#   (NP (LS Stephanopoulos)
#     (NP (LS Analyzes)
#       (NP (PRP$ His)
#         (NP (LS Own) (LS Crime))))))
#
# Gold:
# (ROOT
#   (S
#     (NP (NNP Stephanopoulos))
#     (VP (VBZ Analyzes)
#       (NP (PRP$ His) (JJ Own) (NN Crime)))))
#
#  [Current]    P: 25.00   R: 25.00   F1: 25.00   EX:  0.00
# Guess:
# (ROOT
#   (VP ('' ")
#     (VP (DT These)
#       (VP (VBP are)
#         (VP (RB probably)
#           (VP (DT the)
#             (VP (RBS most)
#               (VP (JJ serious)
#                 (VP (LS allegations)
#                   (VP (RB yet)
#                     (NP (LS leveled)
#                       (NP (IN against)
#                         (NP (DT the)
#                           (NP (NN president) (. .)))))))))))))))
#
# Gold:
# (ROOT
#   (S ('' ")
#     (NP (DT These))
#     (VP (VBP are)
#       (ADVP (RB probably))
#       (NP
#         (NP (DT the)
#           (ADJP (RBS most) (JJ serious))
#           (NNS allegations))
#         (VP
#           (ADVP (RB yet))
#           (VBN leveled)
#           (PP (IN against)
#             (NP (DT the) (NN president))))))
#     (. .)))
#
#  [Current]    P: 25.00   R: 27.27   F1: 26.09   EX:  0.00
# Guess:
# (ROOT
#   (VP (EX There)
#     (S (POS 's)
#       (VP (UH no)
#         (S (NN question)
#           (VP (WDT that)
#             (VP (, ,)
#               (VP (IN if)
#                 (VP (PRP they)
#                   (VP (VBP 're)
#                     (VP (JJ true)
#                       (VP (, ,)
#                         (VP (PRP they)
#                           (VP (NFP ...)
#                             (VP (MD could)
#                               (VP (VB lead)
#                                 (NP (TO to)
#                                   (NP (LS impeachment)
#                                     (NP (NNS proceedings)
#                                       (NP (. .) ('' ")))))))))))))))))))))
#
# Gold:
# (ROOT
#   (S
#     (NP (EX There))
#     (VP (VBZ 's)
#       (NP (DT no) (NN question)
#         (SBAR (IN that) (, ,)
#           (S
#             (SBAR (IN if)
#               (S
#                 (NP (PRP they))
#                 (VP (VBP 're)
#                   (ADJP (JJ true)))))
#             (, ,)
#             (NP (PRP they))
#             (: ...)
#             (VP (MD could)
#               (VP (VB lead)
#                 (PP (TO to)
#                   (NP (NN impeachment) (NNS proceedings)))))))))
#     (. .) ('' ")))
#
#  [Current]    P:  0.00   R:  0.00   F1:  0.00   EX:  0.00
# Guess:
# (ROOT
#   (VP (DT The)
#     (VP (NN problem)
#       (VP (VBZ is)
#         (VP (RB n't)
#           (NP (RB so)
#             (NP (JJ much)
#               (NP (PRP$ his)
#                 (NP (LS disloyalty) (. .))))))))))
#
# Gold:
# (ROOT
#   (S
#     (NP (DT The) (NN problem))
#     (VP (VBZ is) (RB n't)
#       (ADVP (RB so) (RB much))
#       (NP (PRP$ his) (NN disloyalty)))
#     (. .)))
#
#  [Current]    P: 25.00   R: 40.00   F1: 30.77   EX:  0.00
# Guess:
# (ROOT
#   (S (JJ Political)
#     (VP (NNS figures)
#       (VP (VB turn)
#         (VP (RP on)
#           (VP (DT each)
#             (VP (JJ other)
#               (VP (IN from)
#                 (VP (NN time)
#                   (VP (TO to)
#                     (VP (NN time)
#                       (VP (, ,)
#                         (VP (IN for)
#                           (NP (JJ good)
#                             (NP (CC and)
#                               (NP (JJ bad)
#                                 (NP (NNS reasons) (, ;))))))))))))))))))
#
# Gold:
# (ROOT
#   (S
#     (NP (JJ Political) (NNS figures))
#     (VP (VBP turn)
#       (PP (IN on)
#         (NP (DT each) (JJ other)))
#       (PP
#         (PP (IN from)
#           (NP (NN time)))
#         (PP (TO to)
#           (NP (NN time))))
#       (, ,)
#       (PP (IN for)
#         (NP
#           (ADJP (JJ good)
#             (CC and)
#             (JJ bad))
#           (NNS reasons))))
#     (: ;)))
#
#  [Current]    P: 20.00   R: 23.08   F1: 21.43   EX:  0.00
# Guess:
# (ROOT
#   (VP (PRP we)
#     (NP (VBP 're)
#       (NP (VBN used)
#         (NP (TO to)
#           (NP (PRP it) (. .)))))))
#
# Gold:
# (ROOT
#   (S
#     (NP (PRP we))
#     (VP (VBP 're)
#       (ADJP (JJ used)
#         (PP (TO to)
#           (NP (PRP it)))))
#     (. .)))
#
#  [Current]    P: 20.00   R: 16.67   F1: 18.18   EX:  0.00
# Guess:
# (ROOT
#   (S (LS Stephanopoulos)
#     (VP (VBZ wants)
#       (VP (TO to)
#         (VP (VB run)
#           (VP (IN for)
#             (VP (DT the)
#               (VP (NNP Senate)
#                 (VP (CC and)
#                   (VP (VBZ does)
#                     (VP (RB n't)
#                       (VP (VBP want)
#                         (VP (TO to)
#                           (NP (VBP seem)
#                             (NP (DT a)
#                               (NP (NNP Clinton)
#                                 (NP (LS stooge) (. .))))))))))))))))))
#
# Gold:
# (ROOT
#   (S
#     (NP (NNP Stephanopoulos))
#     (VP
#       (VP (VBZ wants)
#         (S
#           (VP (TO to)
#             (VP (VB run)
#               (PP (IN for)
#                 (NP (DT the) (NNP Senate)))))))
#       (CC and)
#       (VP (VBZ does) (RB n't)
#         (VP (VB want)
#           (S
#             (VP (TO to)
#               (VP (VB seem)
#                 (NP (DT a) (NNP Clinton) (NN stooge))))))))
#     (. .)))
#
#  [Current]    P: 37.50   R: 40.00   F1: 38.71   EX:  0.00
# Guess:
# (ROOT
#   (VP (DT The)
#     (VP (NN trouble)
#       (VP (VBZ is)
#         (VP (WDT that)
#           (VP (LS Stephanopoulos)
#             (VP (PRP himself)
#               (VP (VBD helped)
#                 (VP (LS propagate)
#                   (VP (DT those)
#                     (VP (LS lies)
#                       (NP (IN in)
#                         (NP (DT the)
#                           (NP (JJ first)
#                             (NP (NN place) (. .))))))))))))))))
#
# Gold:
# (ROOT
#   (S
#     (NP (DT The) (NN trouble))
#     (VP (VBZ is)
#       (SBAR (IN that)
#         (S
#           (NP
#             (NP (NNP Stephanopoulos))
#             (NP (PRP himself)))
#           (VP (VBD helped)
#             (VP (VB propagate)
#               (NP (DT those) (NNS lies))
#               (PP (IN in)
#                 (NP (DT the) (JJ first) (NN place))))))))
#     (. .)))
#
#  [Current]    P: 28.57   R: 30.77   F1: 29.63   EX:  0.00
# Guess:
# (ROOT
#   (VP (-LRB- -LRB-)
#     (VP (VBP Do)
#       (VP (RB n't)
#         (VP (VB say)
#           (NP (LS Stephanopoulos)
#             (NP (VBD did)
#               (NP (RB n't)
#                 (NP (VBP know) (. .))))))))))
#
# Gold:
# (ROOT
#   (S (-LRB- -LRB-)
#     (VP (VB Do) (RB n't)
#       (VP (VB say)
#         (SBAR
#           (S
#             (NP (NNP Stephanopoulos))
#             (VP (VBD did) (RB n't)
#               (VP (VB know)))))))
#     (. .)))
#
#  [Current]    P: 25.00   R: 25.00   F1: 25.00   EX:  0.00
# Guess:
# (ROOT
#   (VP (RB Again)
#     (VP (, ,)
#       (VP (PRP he)
#         (VP (POS 's)
#           (NP (RB not)
#             (NP (DT a)
#               (NP (LS fool)
#                 (NP (. .) (-RRB- -RRB-))))))))))
#
# Gold:
# (ROOT
#   (S
#     (ADVP (RB Again))
#     (, ,)
#     (NP (PRP he))
#     (VP (VBZ 's) (RB not)
#       (NP (DT a) (NN fool)))
#     (. .) (-RRB- -RRB-)))
#
#  [Current]    P:  0.00   R:  0.00   F1:  0.00   EX:  0.00
# Guess:
# (ROOT
#   (VP (DT The)
#     (VP (CD 1993)
#       (VP (LS documentary)
#         (VP (DT The)
#           (VP (NNP War)
#             (VP (NNP Room)
#               (VP (LS captures)
#                 (VP (DT some)
#                   (VP (IN of)
#                     (NP (PRP$ his)
#                       (NP (NNS efforts)
#                         (NP (RP on)
#                           (NP (NN tape) (. .)))))))))))))))
#
# Gold:
# (ROOT
#   (S
#     (NP
#       (NP (DT The) (CD 1993) (NN documentary))
#       (NP (DT The) (NNP War) (NNP Room)))
#     (VP (VBZ captures)
#       (NP
#         (NP (DT some))
#         (PP (IN of)
#           (NP (PRP$ his) (NNS efforts))))
#       (PP (IN on)
#         (NP (NN tape))))
#     (. .)))
#
#  [Current]    P: 15.38   R: 18.18   F1: 16.67   EX:  0.00
# Guess:
# (ROOT
#   (VP ('' ")
#     (VP (NNP Gov.)
#       (VP (NNP Clinton)
#         (VP (VBZ has)
#           (VP (UH no)
#             (VP (LS character)
#               (VP (NN problem)
#                 (NP (, ,)
#                   (NP ('' ")
#                     (NP (LS Stephanopoulos)
#                       (NP (LS declares) (. .)))))))))))))
#
# Gold:
# (ROOT
#   (S ('' ")
#     (S
#       (NP (NNP Gov.) (NNP Clinton))
#       (VP (VBZ has)
#         (NP (DT no) (NN character) (NN problem))))
#     (, ,) ('' ")
#     (NP (NNP Stephanopoulos))
#     (VP (VBZ declares))
#     (. .)))
#
#  [Current]    P:  0.00   R:  0.00   F1:  0.00   EX:  0.00
# Guess:
# (ROOT
#   (VP (LS Donaldson)
#     (VP (VBZ suggests)
#       (VP (WDT that)
#         (VP (RP on)
#           (VP (CD 60)
#             (VP (LS Minutes)
#               (VP (NNP Clinton)
#                 (NP (VBD had)
#                   (NP (VBN admitted)
#                     (NP (TO to)
#                       (NP (LS infidelity) (. .)))))))))))))
#
# Gold:
# (ROOT
#   (S
#     (NP (NNP Donaldson))
#     (VP (VBZ suggests)
#       (SBAR (IN that)
#         (S
#           (PP (IN on)
#             (NP (NNP 60) (NNPS Minutes)))
#           (NP (NNP Clinton))
#           (VP (VBD had)
#             (VP (VBN admitted)
#               (PP (TO to)
#                 (NP (NN infidelity))))))))
#     (. .)))
#
#  [Current]    P: 18.18   R: 16.67   F1: 17.39   EX:  0.00
# Guess:
# (ROOT
#   (VP (LS Stephanopoulos)
#     (VP (LS skillfully)
#       (VP (LS bullies)
#         (VP (CC and)
#           (VP (LS cajoles)
#             (NP (PRP him)
#               (NP (IN into)
#                 (NP (VBG keeping)
#                   (NP (JJ quiet) (. .)))))))))))
#
# Gold:
# (ROOT
#   (S
#     (NP (NNP Stephanopoulos))
#     (ADVP (RB skillfully))
#     (VP (VBZ bullies)
#       (CC and)
#       (VBZ cajoles)
#       (NP (PRP him))
#       (PP (IN into)
#         (S
#           (VP (VBG keeping)
#             (ADJP (JJ quiet))))))
#     (. .)))
#
#  [Current]    P: 11.11   R: 11.11   F1: 11.11   EX:  0.00
# Guess:
# (ROOT
#   (VP ('' ")
#     (VP (PRP You)
#       (VP (MD would)
#         (VP (VB be)
#           (VP (LS laughed)
#             (VP (IN at)
#               (VP (NFP ...)
#                 (VP ('' ")
#                   (NP (PRP he)
#                     (NP (VBZ tells)
#                       (NP (DT the)
#                         (NP (LS caller) (. .))))))))))))))
#
# Gold:
# (ROOT
#   (S ('' ")
#     (S
#       (NP (PRP You))
#       (VP (MD would)
#         (VP (VB be)
#           (VP (VBN laughed)
#             (PP (IN at))))))
#     (, ...) ('' ")
#     (NP (PRP he))
#     (VP (VBZ tells)
#       (NP (DT the) (NN caller)))
#     (. .)))
#
#  [Current]    P:  0.00   R:  0.00   F1:  0.00   EX:  0.00
# Guess:
# (ROOT
#   (S ('' ")
#     (VP (PRP I)
#       (S (LS guarantee)
#         (VP (PRP you)
#           (VP (WDT that)
#             (VP (IN if)
#               (VP (PRP you)
#                 (VP (VBP do)
#                   (VP (DT this)
#                     (VP (PRP you)
#                       (VP (MD 'll)
#                         (VP (RB never)
#                           (VP (VB work)
#                             (VP (IN in)
#                               (NP (JJ Democratic)
#                                 (NP (NNS politics)
#                                   (NP (RB again)
#                                     (NP (NFP ...) (. .))))))))))))))))))))
#
# Gold:
# (ROOT
#   (S (`` ")
#     (NP (PRP I))
#     (VP (VBP guarantee)
#       (NP (PRP you))
#       (SBAR (IN that)
#         (S
#           (SBAR (IN if)
#             (S
#               (NP (PRP you))
#               (VP (VBP do)
#                 (NP (DT this)))))
#           (NP (PRP you))
#           (VP (MD 'll)
#             (ADVP (RB never))
#             (VP (VB work)
#               (PP (IN in)
#                 (NP (JJ Democratic) (NNS politics)))
#               (ADVP (RB again)))))))
#     (, ...) (. .)))
#
#  [Current]    P:  0.00   R:  0.00   F1:  0.00   EX:  0.00
# Guess:
# (ROOT
#   (VP (NN Nobody)
#     (VP (MD will)
#       (VP (VBP believe)
#         (VP (PRP you)
#           (VP (CC and)
#             (VP (NNS people)
#               (VP (MD will)
#                 (VP (VBP think)
#                   (NP (PRP you)
#                     (NP (VBP 're)
#                       (NP (LS scum)
#                         (NP (. .) ('' "))))))))))))))
#
# Gold:
# (ROOT
#   (S
#     (S
#       (NP (NN Nobody))
#       (VP (MD will)
#         (VP (VB believe)
#           (NP (PRP you)))))
#     (CC and)
#     (S
#       (NP (NNS people))
#       (VP (MD will)
#         (VP (VB think)
#           (SBAR
#             (S
#               (NP (PRP you))
#               (VP (VBP 're)
#                 (ADJP (JJ scum))))))))
#     (. .) ('' ")))
#
#  [Current]    P: 16.67   R: 13.33   F1: 14.81   EX:  0.00
# Guess:
# (ROOT
#   (VP (UH Now)
#     (VP (DT the)
#       (VP (LS dissembler)
#         (VP (CC and)
#           (VP (LS enabler)
#             (VP (VBZ has)
#               (VP (VBN become)
#                 (VP (DT the)
#                   (VP (NN scholar)
#                     (NP (CC and)
#                       (NP (LS ABC)
#                         (NP (NNP News)
#                           (NP (LS analyst) (. .)))))))))))))))
#
# Gold:
# (ROOT
#   (S
#     (ADVP (RB Now))
#     (NP (DT the) (NN dissembler)
#       (CC and)
#       (NN enabler))
#     (VP (VBZ has)
#       (VP (VBN become)
#         (NP (DT the)
#           (NML
#             (NML (NN scholar))
#             (CC and)
#             (NML
#               (NML (NNP ABC) (NNP News))
#               (NN analyst))))))
#     (. .)))
#
#  [Current]    P: 15.38   R: 20.00   F1: 17.39   EX:  0.00
# Guess:
# (ROOT
#   (VP (CC But)
#     (VP (RB usually)
#       (VP (IN at)
#         (VP (JJS least)
#           (VP (DT a)
#             (VP (LS nanosecond)
#               (NP (IN of)
#                 (NP (LS contrition)
#                   (NP (VBZ is)
#                     (NP (VBN required) (. .))))))))))))
#
# Gold:
# (ROOT
#   (S (CC But)
#     (ADVP (RB usually))
#     (NP
#       (NP
#         (QP
#           (ADVP (IN at) (JJS least))
#           (DT a))
#         (NN nanosecond))
#       (PP (IN of)
#         (NP (NN contrition))))
#     (VP (VBZ is)
#       (VP (VBN required)))
#     (. .)))
#
#  [Current]    P:  0.00   R:  0.00   F1:  0.00   EX:  0.00
# Guess:
# (ROOT
#   (VP (LS Stephanopoulos)
#     (S (VBZ is)
#       (VP (LS cashing)
#         (S (IN in)
#           (VP (IN without)
#             (VP (RB even)
#               (VP (VBG going)
#                 (VP (IN through)
#                   (VP (DT the)
#                     (VP (LS minimal)
#                       (VP (NNS motions)
#                         (VP (IN of)
#                           (VP (LS holding)
#                             (VP (PRP himself)
#                               (VP (LS accountable)
#                                 (NP (IN for)
#                                   (NP (JJ misleading)
#                                     (NP (DT the)
#                                       (NP (NN country) (. .)))))))))))))))))))))
#
# Gold:
# (ROOT
#   (S
#     (NP (NNP Stephanopoulos))
#     (VP (VBZ is)
#       (VP (VBG cashing)
#         (PRT (RP in))
#         (PP (IN without)
#           (S
#             (ADVP (RB even))
#             (VP (VBG going)
#               (PP (IN through)
#                 (NP
#                   (NP (DT the) (JJ minimal) (NNS motions))
#                   (PP (IN of)
#                     (S
#                       (VP (VBG holding)
#                         (S
#                           (NP (PRP himself))
#                           (ADJP (JJ accountable)
#                             (PP (IN for)
#                               (S
#                                 (VP (VBG misleading)
#                                   (NP (DT the) (NN country)))))))))))))))))
#     (. .)))
#
#  [Current]    P: 21.05   R: 18.18   F1: 19.51   EX:  0.00
# Guess:
# (ROOT
#   (NP (DT A)
#     (NP (LS Brief) (NN History))))
#
# Gold:
# (ROOT
#   (NP (DT A) (JJ Brief) (NN History)))
#
#  [Current]    P: 50.00   R: 100.00   F1: 66.67   EX:  0.00
# Guess:
# (ROOT
#   (S (LS Around)
#     (VP (LS 7000)
#       (S (LS b.)
#         (VP (LS c.)
#           (VP (, ,)
#             (VP (DT the)
#               (VP (LS Phoenicians)
#                 (VP (VBN set)
#                   (VP (RP out)
#                     (VP (IN from)
#                       (VP (WP what)
#                         (VP (VBZ is)
#                           (VP (RB now)
#                             (VP (NNP Iran)
#                               (NP (TO to)
#                                 (NP (VB explore)
#                                   (NP (PRP$ their)
#                                     (NP (NNS surroundings) (. .))))))))))))))))))))
#
# Gold:
# (ROOT
#   (S
#     (PP (IN Around)
#       (NP (CD 7000) (NN b.) (NN c.)))
#     (, ,)
#     (NP (DT the) (NNPS Phoenicians))
#     (VP (VBD set)
#       (PRT (RP out))
#       (PP (IN from)
#         (SBAR
#           (WHNP (WP what))
#           (S
#             (VP (VBZ is)
#               (ADVP (RB now))
#               (NP (NNP Iran))))))
#       (S
#         (VP (TO to)
#           (VP (VB explore)
#             (NP (PRP$ their) (NNS surroundings))))))
#     (. .)))
#
#  [Current]    P: 17.65   R: 17.65   F1: 17.65   EX:  0.00
# Guess:
# (ROOT
#   (VP (DT An)
#     (VP (JJ important)
#       (VP (JJ early)
#         (VP (NN material)
#           (VP (, ,)
#             (VP (LS obsidian)
#               (VP (, ,)
#                 (VP (VBD was)
#                   (VP (VBD discovered)
#                     (VP (RP on)
#                       (NP (DT the)
#                         (NP (LS island)
#                           (NP (IN of)
#                             (NP (LS Milos) (. .))))))))))))))))
#
# Gold:
# (ROOT
#   (S
#     (NP
#       (NP (DT An) (JJ important) (JJ early) (NN material))
#       (, ,)
#       (NP (NN obsidian)))
#     (, ,)
#     (VP (VBD was)
#       (VP (VBN discovered)
#         (PP (IN on)
#           (NP
#             (NP (DT the) (NN island))
#             (PP (IN of)
#               (NP (NNP Milos)))))))
#     (. .)))
#
#  [Current]    P: 33.33   R: 36.36   F1: 34.78   EX:  0.00
# Guess:
# (ROOT
#   (VP (LS Obsidian)
#     (S (VBZ is)
#       (VP (DT a)
#         (S (JJ hard)
#           (VP (, ,)
#             (VP (LS vitreous)
#               (VP (LS volcanic)
#                 (VP (NN rock)
#                   (VP (, ,)
#                     (VP (WDT which)
#                       (VP (MD could)
#                         (VP (VB be)
#                           (VP (LS fashioned)
#                             (VP (IN into)
#                               (VP (NNS tools)
#                                 (NP (IN for)
#                                   (NP (LS cutting)
#                                     (NP (CC and)
#                                       (NP (LS stabbing) (. .)))))))))))))))))))))
#
# Gold:
# (ROOT
#   (S
#     (NP (NN Obsidian))
#     (VP (VBZ is)
#       (NP
#         (NP (DT a) (JJ hard) (, ,) (JJ vitreous) (JJ volcanic) (NN rock))
#         (, ,)
#         (SBAR
#           (WHNP (WDT which))
#           (S
#             (VP (MD could)
#               (VP (VB be)
#                 (VP (VBN fashioned)
#                   (PP (IN into)
#                     (NP
#                       (NP (NNS tools))
#                       (PP (IN for)
#                         (NP (NN cutting)
#                           (CC and)
#                           (NN stabbing))))))))))))
#     (. .)))
#
#  [Current]    P: 23.53   R: 25.00   F1: 24.24   EX:  0.00
# Guess:
# (ROOT
#   (VP (DT The)
#     (S (JJ high)
#       (VP (NN quality)
#         (VP (IN of)
#           (VP (DT the)
#             (VP (LS seam)
#               (VP (RP on)
#                 (VP (LS Milos)
#                   (VP (LS ensured)
#                     (VP (WDT that)
#                       (VP (DT the)
#                         (VP (NN area)
#                           (VP (LS remained)
#                             (NP (JJ popular)
#                               (NP (IN with)
#                                 (NP (JJ early)
#                                   (NP (LS travelers) (. .)))))))))))))))))))
#
# Gold:
# (ROOT
#   (S
#     (NP
# ...
#
# Gold:
# (ROOT
#   (S
#     (NP (PRP She))
#     (VP (VBD had)
#       (NP
#         (NP (DT the) (NN look))
#         (PP (IN of)
#           (NP
#             (NP (DT every) (NN leader))
#             (SBAR
#               (S
#                 (NP (PRP she))
#                 (VP (VBD had)
#                   (ADVP (RB ever))
#                   (VP (VBN known)))))))))
#     (. .)))
#
#  [Current]    P:  9.09   R:  7.14   F1:  8.00   EX:  0.00
# Guess:
# (ROOT
#   (VP (IN At)
#     (S (CD six)
#       (VP (NN foot)
#         (VP (CD two)
#           (VP (, ,)
#             (VP (PRP she)
#               (VP (VBD stood)
#                 (VP (DT a)
#                   (VP (JJ full)
#                     (VP (NN head)
#                       (VP (LS taller)
#                         (VP (IN than)
#                           (VP (RB even)
#                             (NP (PRP$ her)
#                               (NP (LS Arrallin)
#                                 (NP (JJ first)
#                                   (NP (NN officer) (. .)))))))))))))))))))
#
# Gold:
# (ROOT
#   (S
#     (PP (IN At)
#       (NP
#         (NP (CD six) (NN foot))
#         (NP (CD two))))
#     (, ,)
#     (NP (PRP she))
#     (VP (VBD stood)
#       (S
#         (ADJP
#           (ADJP
#             (NML (DT a) (JJ full) (NN head))
#             (JJR taller))
#           (PP (IN than)
#             (NP (RB even) (PRP$ her) (JJ Arrallin) (JJ first) (NN officer))))))
#     (. .)))
#
#  [Current]    P:  6.25   R:  7.69   F1:  6.90   EX:  0.00
# Guess:
# (ROOT
#   (VP (PRP$ Her)
#     (VP (LS glowering)
#       (VP (NN expression)
#         (NP (VBN completed)
#           (NP (DT the)
#             (NP (LS imposing)
#               (NP (NN effect) (. .)))))))))
#
# Gold:
# (ROOT
#   (S
#     (NP (PRP$ Her) (VBG glowering) (NN expression))
#     (VP (VBD completed)
#       (NP (DT the) (JJ imposing) (NN effect)))
#     (. .)))
#
#  [Current]    P: 14.29   R: 25.00   F1: 18.18   EX:  0.00
# Guess:
# (ROOT
#   (VP (PRP She)
#     (VP (VBN picked)
#       (VP (LS imaginary)
#         (VP (LS flecks)
#           (VP (RP off)
#             (VP (PRP$ her)
#               (VP (LS stark)
#                 (VP (LS gray)
#                   (NP (LS jumpsuit)
#                     (NP (, ,)
#                       (NP (CC and)
#                         (NP (LS snorted) (. .))))))))))))))
#
# Gold:
# (ROOT
#   (S
#     (NP (PRP She))
#     (VP
#       (VP (VBD picked)
#         (NP (JJ imaginary) (NNS flecks))
#         (PP (IN off)
#           (NP (PRP$ her) (JJ stark) (JJ gray) (NN jumpsuit))))
#       (, ,)
#       (CC and)
#       (VP (VBD snorted)))
#     (. .)))
#
#  [Current]    P:  9.09   R: 12.50   F1: 10.53   EX:  0.00
# Guess:
# (ROOT
#   (VP (PRP You)
#     (VP (VB look)
#       (NP (VB like)
#         (NP (LS hell)
#           (NP (, ,)
#             (NP (LS Tar) (. .))))))))
#
# Gold:
# (ROOT
#   (S
#     (NP (PRP You))
#     (VP (VBP look)
#       (PP (IN like)
#         (NP (NN hell)))
#       (, ,)
#       (NP (NNP Tar)))
#     (. .)))
#
#  [Current]    P: 40.00   R: 33.33   F1: 36.36   EX:  0.00
# Guess:
# (ROOT
#   (NP (VBP Do)
#     (NP (RB n't)
#       (NP (LS blow)
#         (NP (DT this) (. .))))))
#
# Gold:
# (ROOT
#   (S
#     (VP (VB Do) (RB n't)
#       (VP (VB blow)
#         (NP (DT this))))
#     (. .)))
#
#  [Current]    P: 25.00   R: 25.00   F1: 25.00   EX:  0.00
# Guess:
# (ROOT
#   (VP (VBP Do)
#     (VP (RB n't)
#       (VP (VB let)
#         (NP (LS fatigue)
#           (NP (VB get)
#             (NP (TO to)
#               (NP (PRP you) (. .)))))))))
#
# Gold:
# (ROOT
#   (S
#     (VP (VB Do) (RB n't)
#       (VP (VB let)
#         (S
#           (NP (NN fatigue))
#           (VP (VB get)
#             (PP (TO to)
#               (NP (PRP you)))))))
#     (. .)))
#
#  [Current]    P: 42.86   R: 37.50   F1: 40.00   EX:  0.00
# Guess:
# (ROOT
#   (VP (PRP She)
#     (VP (VBN used)
#       (VP (DT the)
#         (VP (NN discretion)
#           (VP (IN of)
#             (VP (DT the)
#               (VP (LS mirrored)
#                 (VP (LS window)
#                   (VP (TO to)
#                     (NP (LS secretively)
#                       (NP (NN survey)
#                         (NP (PRP$ her)
#                           (NP (LS crew) (. .)))))))))))))))
#
# Gold:
# (ROOT
#   (S
#     (NP (PRP She))
#     (VP (VBD used)
#       (NP
#         (NP (DT the) (NN discretion))
#         (PP (IN of)
#           (NP (DT the) (JJ mirrored) (NN window))))
#       (S
#         (VP (TO to)
#           (ADVP (RB secretively))
#           (VP (VB survey)
#             (NP (PRP$ her) (NN crew))))))
#     (. .)))
#
#  [Current]    P: 23.08   R: 25.00   F1: 24.00   EX:  0.00
# Guess:
# (ROOT
#   (S (PRP She)
#     (VP (VBD seemed)
#       (S (RB so)
#         (VP (LS depthless)
#           (VP (HYPH -)
#             (VP (NN self)
#               (VP (JJ conscious)
#                 (VP (CC and)
#                   (VP (JJ shallow)
#                     (VP (RP on)
#                       (VP (DT the)
#                         (VP (IN outside)
#                           (VP (, ,)
#                             (VP (CC but)
#                               (NP (VBG having)
#                                 (NP (WDT that)
#                                   (NP (LS incredible)
#                                     (NP (NN gift) (. .))))))))))))))))))))
#
# Gold:
# (ROOT
#   (S
#     (NP (PRP She))
#     (VP (VBD seemed)
#       (S
#         (ADJP
#           (ADJP (RB so) (JJ depthless))
#           (: -)
#           (UCP
#             (ADJP
#               (ADJP
#                 (ADJP (NN self) (JJ conscious))
#                 (CC and)
#                 (ADJP (JJ shallow)))
#               (PP (IN on)
#                 (NP (DT the) (NN outside))))
#             (, ,)
#             (CC but)
#             (S
#               (VP (VBG having)
#                 (NP (DT that) (JJ incredible) (NN gift))))))))
#     (. .)))
#
#  [Current]    P:  0.00   R:  0.00   F1:  0.00   EX:  0.00
# Guess:
# (ROOT
#   (VP (EX There)
#     (VP (VBD had)
#       (VP (TO to)
#         (NP (VB be)
#           (NP (RBR more)
#             (NP (TO to)
#               (NP (PRP$ her) (. .)))))))))
#
# Gold:
# (ROOT
#   (S
#     (NP (EX There))
#     (VP (VBD had)
#       (S
#         (VP (TO to)
#           (VP (VB be)
#             (NP
#               (NP (JJR more))
#               (PP (TO to)
#                 (NP (PRP her))))))))
#     (. .)))
#
#  [Current]    P: 57.14   R: 40.00   F1: 47.06   EX:  0.00
# Guess:
# (ROOT
#   (VP (UH Well)
#     (VP (, ,)
#       (VP (IN if)
#         (VP (PRP she)
#           (VP (VBD did)
#             (VP (RB n't)
#               (VP (LS pan)
#                 (VP (RP out)
#                   (VP (, ,)
#                     (NP (PRP she)
#                       (NP (MD 'd)
#                         (NP (VB be)
#                           (NP (VBN terminated) (. .)))))))))))))))
#
# Gold:
# (ROOT
#   (S
#     (INTJ (UH Well))
#     (, ,)
#     (SBAR (IN if)
#       (S
#         (NP (PRP she))
#         (VP (VBD did) (RB n't)
#           (VP (VB pan)
#             (PRT (RP out))))))
#     (, ,)
#     (NP (PRP she))
#     (VP (MD 'd)
#       (VP (VB be)
#         (VP (VBN terminated))))
#     (. .)))
#
#  [Current]    P:  0.00   R:  0.00   F1:  0.00   EX:  0.00
# Guess:
# (ROOT
#   (VP (DT Any)
#     (VP (LS crew)
#       (VP (NN member)
#         (VP (WDT that)
#           (VP (MD would)
#             (VP (LS jeopardize)
#               (NP (DT the)
#                 (NP (NN project)
#                   (NP (VBD was)
#                     (NP (LS meat) (. .))))))))))))
#
# Gold:
# (ROOT
#   (S
#     (NP
#       (NP (DT Any) (NN crew) (NN member))
#       (SBAR
#         (WHNP (WDT that))
#         (S
#           (VP (MD would)
#             (VP (VB jeopardize)
#               (NP (DT the) (NN project)))))))
#     (VP (VBD was)
#       (NP (NN meat)))
#     (. .)))
#
#  [Current]    P: 10.00   R:  9.09   F1:  9.52   EX:  0.00
# Guess:
# (ROOT
#   (VP (PRP It)
#     (VP (MD would)
#       (VP (VB be)
#         (VP (DT a)
#           (VP (LS shame)
#             (VP (TO to)
#               (VP (VBP lose)
#                 (NP (WDT that)
#                   (NP (LS talent)
#                     (NP (, ,)
#                       (NP (IN though) (. .)))))))))))))
#
# Gold:
# (ROOT
#   (S
#     (NP (PRP It))
#     (VP (MD would)
#       (VP (VB be)
#         (NP (DT a) (NN shame))
#         (S
#           (VP (TO to)
#             (VP (VB lose)
#               (NP (DT that) (NN talent)))))
#         (, ,)
#         (ADVP (RB though))))
#     (. .)))
#
#  [Current]    P: 20.00   R: 20.00   F1: 20.00   EX:  0.00
# Guess:
# (ROOT
#   (VP (LS Rakal)
#     (VP (, ,)
#       (VP (PRP$ her)
#         (VP (JJ first)
#           (VP (NN officer)
#             (VP (, ,)
#               (VP (VBD was)
#                 (VP (LS staring)
#                   (NP (LS pensively)
#                     (NP (IN at)
#                       (NP (PRP$ his)
#                         (NP (NN panel) (. .))))))))))))))
#
# Gold:
# (ROOT
#   (S
#     (NP
#       (NP (NNP Rakal))
#       (, ,)
#       (NP (PRP$ her) (JJ first) (NN officer)))
#     (, ,)
#     (VP (VBD was)
#       (VP (VBG staring)
#         (ADVP (RB pensively))
#         (PP (IN at)
#           (NP (PRP$ his) (NN panel)))))
#     (. .)))
#
#  [Current]    P: 30.00   R: 33.33   F1: 31.58   EX:  0.00
# Guess:
# (ROOT
#   (VP (PRP He)
#     (VP (VBD was)
#       (VP (WP what)
#         (NP (DT this)
#           (NP (VBD was)
#             (NP (PDT all)
#               (NP (IN about) (. .)))))))))
#
# Gold:
# (ROOT
#   (S
#     (NP (PRP He))
#     (VP (VBD was)
#       (SBAR
#         (WHNP (WP what))
#         (S
#           (NP (DT this))
#           (VP (VBD was)
#             (PP
#               (ADVP (RB all))
#               (IN about))))))
#     (. .)))
#
#  [Current]    P: 14.29   R: 10.00   F1: 11.76   EX:  0.00
# Guess:
# (ROOT
#   (S (PRP She)
#     (VP (LS watched)
#       (VP (PRP$ his)
#         (VP (JJ graceful)
#           (VP (NNS fingers)
#             (VP (LS ending)
#               (VP (IN in)
#                 (VP (RB thick)
#                   (VP (JJ black)
#                     (VP (LS claws)
#                       (VP (VB tap)
#                         (VP (RP out)
#                           (NP (LS calculations)
#                             (NP (RP on)
#                               (NP (DT the)
#                                 (NP (NN panel) (. .))))))))))))))))))
#
# Gold:
# (ROOT
#   (S
#     (NP (PRP She))
#     (VP (VBD watched)
#       (S
#         (NP
#           (NP (PRP$ his) (JJ graceful) (NNS fingers))
#           (VP (VBG ending)
#             (PP (IN in)
#               (NP (JJ thick) (JJ black) (NNS claws)))))
#         (VP (VB tap)
#           (PRT (RP out))
#           (NP (NNS calculations))
#           (PP (IN on)
#             (NP (DT the) (NN panel))))))
#     (. .)))
#
#  [Current]    P: 25.00   R: 28.57   F1: 26.67   EX:  0.00
# Guess:
# (ROOT
#   (VP (RB Only)
#     (S (DT those)
#       (VP (IN of)
#         (VP (DT the)
#           (VP (LS Arrallin)
#             (VP (LS Insurrection)
#               (VP (JJ inner)
#                 (VP (NN team)
#                   (VP (VBD knew)
#                     (VP (PRP he)
#                       (VP (VBD was)
#                         (VP (UH no)
#                           (VP (JJ common)
#                             (NP ('' ')
#                               (NP (LS beta)
#                                 (NP (LS furry)
#                                   (NP ('' ') (. .)))))))))))))))))))
#
# Gold:
# (ROOT
#   (S
#     (NP
#       (NP (RB Only) (DT those))
#       (PP (IN of)
#         (NP (DT the)
#           (NML (NNP Arrallin) (NNP Insurrection))
#           (JJ inner) (NN team))))
#     (VP (VBD knew)
#       (SBAR
#         (S
#           (NP (PRP he))
#           (VP (VBD was)
#             (NP (DT no) (JJ common) (`` ') (NN beta) (NN furry) ('' '))))))
#     (. .)))
#
#  [Current]    P: 12.50   R: 16.67   F1: 14.29   EX:  0.00
# Guess:
# (ROOT
#   (VP (UH Right)
#     (VP (RB now)
#       (VP (, ,)
#         (VP (PRP he)
#           (VP (VBD looked)
#             (VP (VB like)
#               (VP (DT an)
#                 (VP (LS overgrown)
#                   (VP (LS wolf)
#                     (VP (WP who)
#                       (VP (MD 'd)
#                         (NP (VBD learned)
#                           (NP (VB touch)
#                             (NP (HYPH -)
#                               (NP (VBG typing) (. .)))))))))))))))))
#
# Gold:
# (ROOT
#   (S
#     (ADVP (RB Right) (RB now))
#     (, ,)
#     (NP (PRP he))
#     (VP (VBD looked)
#       (PP (IN like)
#         (NP
#           (NP (DT an) (JJ overgrown) (NN wolf))
#           (SBAR
#             (WHNP (WP who))
#             (S
#               (VP (VBD 'd)
#                 (VP (VBN learned)
#                   (NP (NN touch) (HYPH -) (NN typing)))))))))
#     (. .)))
#
#  [Current]    P: 21.43   R: 23.08   F1: 22.22   EX:  0.00
# Guess:
# (ROOT
#   (S (DT The)
#     (VP (LS scout)
#       (S (NN ship)
#         (VP (LS re-emerged)
#           (VP (IN from)
#             (VP (DT the)
#               (VP (NN hole)
#                 (VP (HYPH -)
#                   (VP (DT a)
#                     (VP (JJ brilliant)
#                       (VP (LS speck)
#                         (VP (VBG emerging)
#                           (VP (IN from)
#                             (VP (DT a)
#                               (NP (LS sphere)
#                                 (NP (IN of)
#                                   (NP (LS velvety)
#                                     (NP (LS blackness) (. .))))))))))))))))))))
#
# Gold:
# (ROOT
#   (S
#     (NP (DT The) (NN scout) (NN ship))
#     (VP (VBD re-emerged)
#       (PP (IN from)
#         (NP (DT the) (NN hole)))
#       (: -)
#       (S
#         (NP (DT a) (JJ brilliant) (NN speck))
#         (VP (VBG emerging)
#           (PP (IN from)
#             (NP
#               (NP (DT a) (NN sphere))
#               (PP (IN of)
#                 (NP (JJ velvety) (NN blackness))))))))
#     (. .)))
#
#  [Current]    P:  0.00   R:  0.00   F1:  0.00   EX:  0.00
# Guess:
# (ROOT
#   (VP (LS It's)
#     (S (LS hail)
#       (VP (LS crackled)
#         (VP (IN across)
#           (VP (DT the)
#             (VP (LS comm)
#               (VP (, ,)
#                 (VP (CC and)
#                   (VP (LS Tara)
#                     (VP (LS spun)
#                       (VP (TO to)
#                         (VP (LS retake)
#                           (VP (PRP$ her)
#                             (NP (NN seat)
#                               (NP (IN at)
#                                 (NP (DT the)
#                                   (NP (LS helm) (. .)))))))))))))))))))
#
# Gold:
# (ROOT
#   (S
#     (S
#       (NP (PRP$ It's) (NN hail))
#       (VP (VBD crackled)
#         (PP (IN across)
#           (NP (DT the) (NN comm)))))
#     (, ,)
#     (CC and)
#     (S
#       (NP (NNP Tara))
#       (VP (VBD spun)
#         (S
#           (VP (TO to)
#             (VP (VB retake)
#               (NP
#                 (NP (PRP$ her) (NN seat))
#                 (PP (IN at)
#                   (NP (DT the) (NN helm)))))))))
#     (. .)))
#
#  [Current]    P: 25.00   R: 25.00   F1: 25.00   EX:  0.00
# Guess:
# (ROOT
#   (VP ('' ")
#     (NP (LS Launch)
#       (NP (DT the)
#         (NP (JJ second)
#           (NP (LS probe) (. .)))))))
#
# Gold:
# (ROOT
#   (S (`` ")
#     (VP (VB Launch)
#       (NP (DT the) (JJ second) (NN probe)))
#     (. .)))
#
#  [Current]    P: 40.00   R: 66.67   F1: 50.00   EX:  0.00
# Guess:
# (ROOT
#   (VP (LS Level)
#     (VP (LS 1)
#       (VP (CC and)
#         (VP (LS 2)
#           (VP (LS staffers)
#             (VP (MD should)
#               (VP (VB prepare)
#                 (VP (TO to)
#                   (VP (VB be)
#                     (NP (VBD briefed)
#                       (NP (CC and)
#                         (NP (VB move)
#                           (NP (RP out) (. .)))))))))))))))
#
# Gold:
# (ROOT
#   (S
#     (NP
#       (NML (NN Level) (CD 1)
#         (CC and)
#         (CD 2))
#       (NNS staffers))
#     (VP (MD should)
#       (VP (VB prepare)
#         (S
#           (VP (TO to)
#             (VP
#               (VP (VB be)
#                 (VP (VBN briefed)))
#               (CC and)
#               (VP (VB move)
#                 (PRT (RP out))))))))
#     (. .)))
#
#  [Current]    P: 30.77   R: 33.33   F1: 32.00   EX:  0.00
# Guess:
# (ROOT
#   (VP (DT This)
#     (VP (VBZ sounds)
#       (VP (VB like)
#         (VP (PRP it)
#           (NP (POS 's)
#             (NP (DT the)
#               (NP (CD one)
#                 (NP (. .) ('' "))))))))))
#
# Gold:
# (ROOT
#   (S
#     (NP (DT This))
#     (VP (VBZ sounds)
#       (SBAR (IN like)
#         (S
#           (NP (PRP it))
#           (VP (VBZ 's)
#             (NP (DT the) (NN one))))))
#     (. .) ('' ")))
#
#  [Current]    P: 25.00   R: 25.00   F1: 25.00   EX:  0.00
#
#  [Average]    P: 19.92   R: 21.72   F1: 20.78   EX:  3.64

# %% [markdown]
# Notice we also provide you with run scripts in the `python/` directory that has the commands required to run the program. You can run this script by calling `./run` in the `python/` directory.

# %% [markdown]
# ----
# Your Task
# -----
#
# Your first job is to build a parser using this grammar. For the `miniTest` dataset your parser should match the given parse of the test sentence exactly. Once you've got this working you can move on to the MASC dataset.
#
# Scan through a few of the training trees in the MASC dataset to get a sense of the range of inputs. Something you'll notice is that the grammar has relatively few non-terminal symbols but thousands of rules, many ternary-branching or longer. Currently there are 38 MASC train files and 11 test files. (You can look in the data directory if you're curious about the native format of these files.) The static integer `MAX_LENGTH` determines the maximum length of sentences to test on (it does not affect the training set). You can lower `MAX_LENGTH` for preliminary experiments, but your final parser should work on sentences of up to length 20 in a reasonable time.
#
# Once you have a parser working on the treebank, your next task is improve upon the supplied grammar by adding 2nd-order vertical markovization. This means using parent annotation symbols like NP^S to indicate a subject noun phrase instead of just NP. You can test your new grammar on the miniTest data set if you want, though the results won't be very interesting. When you test it on the treebank the results will be minimal but substantive (a 2% improvement over the parser using the original grammar). At this point an F1 performance in the mid-70% range is achievable.
#
# All in all, there are only places in the code (all in `PCFGParserTester`) that you will have to fill in your own code are marked with the usual `TODO` markers.
#
# The first two are __required__.
#
# The third one is __optional__.

# %%
# %load PCFGParserTester

# %%
# %load PCFGParserTester
import collections
import copy
import optparse

from ling.Tree import Tree
import ling.Trees as Trees
import pennParser.EnglishPennTreebankParseEvaluator as \
        EnglishPennTreebankParseEvaluator
import io.PennTreebankReader as PennTreebankReader
import io.MASCTreebankReader as MASCTreebankReader


class Parser:

    def train(self, train_trees):
        pass

    def get_best_parse(self, sentence):
        """
        Should return a Tree
        """
        pass


class PCFGParser(Parser):

    def train(self, train_trees):
        # TODO: before you generate your grammar, the training
        #       trees need to be binarized so that rules are at
        #       most binary

        self.lexicon = Lexicon(train_trees)
        self.grammar = Grammar(train_trees)


    def get_best_parse(self, sentence):
        """
        Should return a Tree.
        'sentence' is a list of strings (words) that form a sentence.
        """
        # TODO: implement this method

        return None


class BaselineParser(Parser):

    def train(self, train_trees):
        self.lexicon = Lexicon(train_trees)
        self.known_parses = {}
        self.span_to_categories = {}
        for train_tree in train_trees:
            tags = train_tree.get_preterminal_yield()
            tags = tuple(tags)  # because lists are not hashable, but tuples are
            if tags not in self.known_parses:
                self.known_parses[tags] = {}
            if train_tree not in self.known_parses[tags]:
                self.known_parses[tags][train_tree] = 1
            else:
                self.known_parses[tags][train_tree] += 1
            self.tally_spans(train_tree, 0)

    def get_best_parse(self, sentence):
        tags = self.get_baseline_tagging(sentence)
        tags = tuple(tags)
        if tags in self.known_parses:
            return self.get_best_known_parse(tags, sentence)
        else:
            return self.build_right_branch_parse(sentence, list(tags))

    def build_right_branch_parse(self, words, tags):
        cur_position = len(words) - 1
        right_branch_tree = self.build_tag_tree(words, tags, cur_position)
        while cur_position > 0:
            cur_position -= 1
            right_branch_tree = self.merge(
                    self.build_tag_tree(words, tags, cur_position),
                    right_branch_tree)
        right_branch_tree = self.add_root(right_branch_tree)
        return right_branch_tree

    def merge(self, left_tree, right_tree):
        span = len(left_tree.get_yield()) + len(right_tree.get_yield())
        maxval = max(self.span_to_categories[span].values())
        for key in self.span_to_categories[span]:
            if self.span_to_categories[span][key] == maxval:
                most_freq_label = key
                break
        return Tree(most_freq_label, [left_tree, right_tree])

    def add_root(self, tree):
        return Tree("ROOT", [tree])

    def build_tag_tree(self, words, tags, cur_position):
        leaf_tree = Tree(words[cur_position])
        tag_tree = Tree(tags[cur_position], [leaf_tree])
        return tag_tree

    def get_best_known_parse(self, tags, sentence):
        maxval = max(self.known_parses[tags].values())
        for key in self.known_parses[tags]:
            if self.known_parses[tags][key] == maxval:
                parse = key
                break
        parse = copy.deepcopy(parse)
        parse.set_words(sentence)
        return parse

    def get_baseline_tagging(self, sentence):
        tags = [self.get_best_tag(word) for word in sentence]
        return tags

    def get_best_tag(self, word):
        best_score = 0
        best_tag = None
        for tag in self.lexicon.get_all_tags():
            score = self.lexicon.score_tagging(word, tag)
            if best_tag is None or score > best_score:
                best_score = score
                best_tag = tag
        return best_tag

    def tally_spans(self, tree, start):
        if tree.is_leaf() or tree.is_preterminal():
            return 1
        end = start
        for child in tree.children:
            child_span = self.tally_spans(child, end)
            end += child_span
        category = tree.label
        if category != "ROOT":
            if end-start not in self.span_to_categories:
                self.span_to_categories[end-start] = {}
            if category not in self.span_to_categories[end-start]:
                self.span_to_categories[end-start][category] = 1
            else:
                self.span_to_categories[end-start][category] += 1
        return end - start


class TreeAnnotations:

    @classmethod
    def annotate_tree(cls, unannotated_tree):
        """
        Currently, the only annotation done is a lossless binarization
        """

        # TODO: change the annotation from a lossless binarization to a
        # finite-order markov process (try at least 1st and 2nd order)
        # mark nodes with the label of their parent nodes, giving a second
        # order vertical markov process

        return TreeAnnotations.binarize_tree(unannotated_tree)

    @classmethod
    def binarize_tree(cls, tree):
        label = tree.label
        if tree.is_leaf():
            return Tree(label)
        if len(tree.children) == 1:
            return Tree(label, [TreeAnnotations.binarize_tree(tree.children[0])])

        intermediate_label = "@%s->" % label
        intermediate_tree = TreeAnnotations.binarize_tree_helper(
                tree, 0, intermediate_label)
        return Tree(label, intermediate_tree.children)

    @classmethod
    def binarize_tree_helper(cls, tree, num_children_generated,
            intermediate_label):
        left_tree = tree.children[num_children_generated]
        children = []
        children.append(TreeAnnotations.binarize_tree(left_tree))
        if num_children_generated < len(tree.children) - 1:
            right_tree = TreeAnnotations.binarize_tree_helper(
                    tree, num_children_generated + 1,
                    intermediate_label + "_" + left_tree.label)
            children.append(right_tree)
        return Tree(intermediate_label, children)


    @classmethod
    def at_filter(cls, string):
        if string.startswith('@'):
            return True
        else:
            return False

    @classmethod
    def unannotate_tree(cls, annotated_tree):
        """
        Remove intermediate nodes (labels beginning with "@")
        Remove all material on node labels which follow their base
        symbol (cuts at the leftmost -, ^, or : character)
        Examples: a node with label @NP->DT_JJ will be spliced out,
        and a node with label NP^S will be reduced to NP
        """
        debinarized_tree = Trees.splice_nodes(annotated_tree,
                TreeAnnotations.at_filter)
        unannotated_tree = Trees.FunctionNodeStripper.transform_tree(
                debinarized_tree)
        return unannotated_tree


class Lexicon:
    """
    Simple default implementation of a lexicon, which scores word,
    tag pairs with a smoothed estimate of P(tag|word)/P(tag).

    Instance variables:
    word_to_tag_counters
    total_tokens
    total_word_types
    tag_counter
    word_counter
    type_tag_counter
    """

    def __init__(self, train_trees):
        """
        Builds a lexicon from the observed tags in a list of training
        trees.
        """
        self.total_tokens = 0.0
        self.total_word_types = 0.0
        self.word_to_tag_counters = collections.defaultdict(lambda: \
                collections.defaultdict(lambda: 0.0))
        self.tag_counter = collections.defaultdict(lambda: 0.0)
        self.word_counter = collections.defaultdict(lambda: 0.0)
        self.type_to_tag_counter = collections.defaultdict(lambda: 0.0)

        for train_tree in train_trees:
            words = train_tree.get_yield()
            tags = train_tree.get_preterminal_yield()
            for word, tag in zip(words, tags):
                self.tally_tagging(word, tag)


    def tally_tagging(self, word, tag):
        if not self.is_known(word):
            self.total_word_types += 1
            self.type_to_tag_counter[tag] += 1
        self.total_tokens += 1
        self.tag_counter[tag] += 1
        self.word_counter[word] += 1
        self.word_to_tag_counters[word][tag] += 1


    def get_all_tags(self):
        return self.tag_counter.keys()


    def is_known(self, word):
        return word in self.word_counter


    def score_tagging(self, word, tag):
        p_tag = float(self.tag_counter[tag]) / self.total_tokens
        c_word = float(self.word_counter[word])
        c_tag_and_word = float(self.word_to_tag_counters[word][tag])
        if c_word < 10:
            c_word += 1
            c_tag_and_word += float(self.type_to_tag_counter[tag]) \
                    / self.total_word_types
        p_word = (1.0 + c_word) / (self.total_tokens + self.total_word_types)
        p_tag_given_word = c_tag_and_word / c_word
        return p_tag_given_word / p_tag * p_word


class Grammar:
    """
    Simple implementation of a PCFG grammar, offering the ability to
    look up rules by their child symbols.  Rule probability estimates
    are just relative frequency estimates off of training trees.

    self.binary_rules_by_left_child
    self.binary_rules_by_right_child
    self.unary_rules_by_child
    """

    def __init__(self, train_trees):
        self.unary_rules_by_child = collections.defaultdict(lambda: [])
        self.binary_rules_by_left_child = collections.defaultdict(
                lambda: [])
        self.binary_rules_by_right_child = collections.defaultdict(
                lambda: [])

        unary_rule_counter = collections.defaultdict(lambda: 0)
        binary_rule_counter = collections.defaultdict(lambda: 0)
        symbol_counter = collections.defaultdict(lambda: 0)

        for train_tree in train_trees:
            self.tally_tree(train_tree, symbol_counter,
                    unary_rule_counter, binary_rule_counter)
        for unary_rule in unary_rule_counter:
            unary_prob = float(unary_rule_counter[unary_rule]) \
                    / symbol_counter[unary_rule.parent]
            unary_rule.score = unary_prob
            self.add_unary(unary_rule)
        for binary_rule in binary_rule_counter:
            binary_prob = float(binary_rule_counter[binary_rule]) \
                    / symbol_counter[binary_rule.parent]
            binary_rule.score = binary_prob
            self.add_binary(binary_rule)


    def __unicode__(self):
        rule_strings = []
        for left_child in self.binary_rules_by_left_child:
            for binary_rule in self.get_binary_rules_by_left_child(
                    left_child):
                rule_strings.append(str(binary_rule))
        for child in self.unary_rules_by_child:
            for unary_rule in self.get_unary_rules_by_child(child):
                rule_strings.append(str(unary_rule))
        return "%s\n" % "".join(rule_strings)


    def add_binary(self, binary_rule):
        self.binary_rules_by_left_child[binary_rule.left_child].\
                append(binary_rule)
        self.binary_rules_by_right_child[binary_rule.right_child].\
                append(binary_rule)


    def add_unary(self, unary_rule):
        self.unary_rules_by_child[unary_rule.child].append(unary_rule)


    def get_binary_rules_by_left_child(self, left_child):
        return self.binary_rules_by_left_child[left_child]


    def get_binary_rules_by_right_child(self, right_child):
        return self.binary_rules_by_right_child[right_child]


    def get_unary_rules_by_child(self, child):
        return self.unary_rules_by_child[child]


    def tally_tree(self, tree, symbol_counter, unary_rule_counter,
            binary_rule_counter):
        if tree.is_leaf():
            return
        if tree.is_preterminal():
            return
        if len(tree.children) == 1:
            unary_rule = self.make_unary_rule(tree)
            symbol_counter[tree.label] += 1
            unary_rule_counter[unary_rule] += 1
        if len(tree.children) == 2:
            binary_rule = self.make_binary_rule(tree)
            symbol_counter[tree.label] += 1
            binary_rule_counter[binary_rule] += 1
        if len(tree.children) < 1 or len(tree.children) > 2:
            raise Exception("Attempted to construct a Grammar with " \
                    + "an illegal tree (most likely not binarized): " \
                    + str(tree))
        for child in tree.children:
            self.tally_tree(child, symbol_counter, unary_rule_counter,
                    binary_rule_counter)


    def make_unary_rule(self, tree):
        return UnaryRule(tree.label, tree.children[0].label)


    def make_binary_rule(self, tree):
        return BinaryRule(tree.label, tree.children[0].label,
                tree.children[1].label)


class BinaryRule:
    """
    A binary grammar rule with score representing its probability.
    """

    def __init__(self, parent, left_child, right_child):
        self.parent = parent
        self.left_child = left_child
        self.right_child = right_child
        self.score = 0.0


    def __str__(self):
        return "%s->%s %s %% %s" % (self.parent, self.left_child, self.right_child, self.score)


    def __hash__(self):
        result = hash(self.parent)
        result = 29 * result + hash(self.left_child)
        result = 29 * result + hash(self.right_child)
        return result


    def __eq__(self, o):
        if self is o:
            return True

        if not isinstance(o, BinaryRule):
            return False

        if (self.left_child != o.left_child):
            return False
        if (self.right_child != o.right_child):
            return False
        if (self.parent != o.parent):
            return False
        return True


class UnaryRule:
    """
    A unary grammar rule with score representing its probability.
    """

    def __init__(self, parent, child):
        self.parent = parent
        self.child = child
        self.score = 0.0

    def __str__(self):
        return "%s->%s %% %s" % (self.parent, self.child, self.score)

    def __hash__(self):
        result = hash(self.parent)
        result = 29 * result + hash(self.child)
        return result

    def __eq__(self, o):
        if self is o:
            return True

        if not isinstance(o, UnaryRule):
            return False

        if (self.child != o.child):
            return False
        if (self.parent != o.parent):
            return False
        return True


MAX_LENGTH = 20

def test_parser(parser, test_trees):
    evaluator = EnglishPennTreebankParseEvaluator.LabeledConstituentEval(
            ["ROOT"], set(["''", "``", ".", ":", ","]))
    for test_tree in test_trees:
        test_sentence = test_tree.get_yield()
        if len(test_sentence) > 20:
            continue
        guessed_tree = parser.get_best_parse(test_sentence)
        print "Guess:\n%s" % Trees.PennTreeRenderer.render(guessed_tree)
        print "Gold:\n%s" % Trees.PennTreeRenderer.render(test_tree)
        evaluator.evaluate(guessed_tree, test_tree)
    print ""
    return evaluator.display(True)


def read_trees(base_path, low=None, high=None):
    trees = PennTreebankReader.read_trees(base_path, low, high)
    return [Trees.StandardTreeNormalizer.transform_tree(tree) \
        for tree in trees]


def read_masc_trees(base_path, low=None, high=None):
    print "Reading MASC from %s" % base_path
    trees = MASCTreebankReader.read_trees(base_path, low, high)
    return [Trees.StandardTreeNormalizer.transform_tree(tree) \
        for tree in trees]


if __name__ == '__main__':
    opt_parser = optparse.OptionParser()
    opt_parser.add_option("--path", dest="path",
            default="../data/parser")
    opt_parser.add_option("--data", dest="data", default = "masc")
    opt_parser.add_option("--parser", dest="parser",
            default="BaselineParser")
    opt_parser.add_option("--maxLength", dest="max_length",
            default="20")
    opt_parser.add_option("--testData", dest="test_data", default="")

    (options, args) = opt_parser.parse_args()
    options = vars(options)

    print "PCFGParserTest options:"
    for opt in options:
        print "  %-12s: %s" % (opt, options[opt])
    print ""
    MAX_LENGTH = int(options['max_length'])

    parser = globals()[options['parser']]()
    print "Using parser: %s" % parser.__class__.__name__

    base_path = options['path']
    pre_base_path = base_path
    data_set = options['data']
    if not base_path.endswith('/'):
        base_path += '/'

    print "Data will be loaded from: %s" % base_path

    train_trees = []
    validation_trees = []
    test_trees = []

    if data_set == 'miniTest':
        base_path += 'parser/%s' % data_set

        # training data: first 3 of 4 datums
        print "Loading training trees..."
        train_trees = read_trees(base_path, 1, 3)
        print "done."

        # test data: last of 4 datums
        print "Loading test trees..."
        test_trees = read_trees(base_path, 4, 4)
        print "done."

    if data_set == "masc":
        base_path += "parser/"

        # training data: MASC train
        print "Loading MASC training trees... from: %smasc/train" % base_path
        train_trees.extend(read_masc_trees("%smasc/train" % base_path, 0, 38))
        print "done."
        print "Train trees size: %d" % len(train_trees)
        print "First train tree: %s" % \
                Trees.PennTreeRenderer.render(train_trees[0])
        print "Last train tree: %s" % \
                Trees.PennTreeRenderer.render(train_trees[-1])

        # test data: MASC devtest
        print "Loading MASC test trees..."
        test_trees.extend(read_masc_trees("%smasc/devtest" % base_path, 0, 11))
        #test_trees.extend(read_masc_trees("%smasc/blindtest" % base_path, 0, 8))
        print "done."
        print "Test trees size: %d" % len(test_trees)
        print "First test tree: %s" % \
                Trees.PennTreeRenderer.render(test_trees[0])
        print "Last test tree: %s" % \
                Trees.PennTreeRenderer.render(test_trees[-1])


    if data_set not in ["miniTest", "masc"]:
        raise Exception("Bad data set: %s: use miniTest or masc." % data_set)

    print ""
    print "Training parser..."
    parser.train(train_trees)

    print "Testing parser"
    test_parser(parser, test_trees)
