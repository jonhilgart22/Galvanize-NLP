# %% [markdown]
# ---
# Relation Extraction Exercises
# =====

# %% [markdown]
# <img src="http://www.accessola2.com/olita/insideolita/wordpress/wp-content/uploads/2014/04/hitchens_app2_Slide9.jpg" style="width: 600px;"/>
#
# We are going to explore [RDFLib](https://github.com/RDFLib/rdflib)

# %%
reset -fs

# %%
from io import StringIO

try:
    import rdflib
except ImportError:
    import pip
    pip.main(["install", "rdflib"])
    import rdflib
# Out:
# Collecting rdflib
#   Downloading rdflib-4.2.1.tar.gz (889kB)
# Collecting isodate (from rdflib)
#   Downloading isodate-0.5.4.tar.gz
# Requirement already satisfied (use --upgrade to upgrade): pyparsing in /Users/brianspiering/anaconda/envs/py3_nlp/lib/python3.5/site-packages (from rdflib)
# Building wheels for collected packages: rdflib, isodate
#   Running setup.py bdist_wheel for rdflib: started
#   Running setup.py bdist_wheel for rdflib: finished with status 'done'
#   Stored in directory: /Users/brianspiering/Library/Caches/pip/wheels/5f/cc/22/bba65aa21c61d538dffb4960bd74ece936f3b0ef71ade47fb5
#   Running setup.py bdist_wheel for isodate: started
#   Running setup.py bdist_wheel for isodate: finished with status 'done'
#   Stored in directory: /Users/brianspiering/Library/Caches/pip/wheels/8a/b6/2c/9346712a1822e562d16c4d6a5ae242ebf45128a8cb2e7b4abe
# Successfully built rdflib isodate
# Installing collected packages: isodate, rdflib
# Successfully installed isodate-0.5.4 rdflib-4.2.1
# RDFLib Version: 4.2.1

# %%
contents = '''subject|predicate|object
Jill|Likes|Snowboarding
Snowboarding|Is a|Sport
'''  

fake_file = StringIO(contents)

# %%
graph = rdflib.Graph()

for line in fake_file:
    triple = line.split("|")                       # triple is now a list of 3 strings
    triple = (rdflib.URIRef(t) for t in triple) # we have to wrap them in URIRef
    graph.add(triple)                           # and add to the graph
# Out:
# Is a does not look like a valid URI, trying to serialize this will break.

# %%
graph.

# %%
list(graph.subjects())
# Out:
# [rdflib.term.URIRef('subject'),
#  rdflib.term.URIRef('Snowboarding'),
#  rdflib.term.URIRef('Jill')]

# %%
list(graph.subject_predicates())
# Out:
# [(rdflib.term.URIRef('subject'), rdflib.term.URIRef('predicate')),
#  (rdflib.term.URIRef('Snowboarding'), rdflib.term.URIRef('Is a')),
#  (rdflib.term.URIRef('Jill'), rdflib.term.URIRef('Likes'))]

# %%
list(graph.subject_objects())
# Out:
# [(rdflib.term.URIRef('subject'), rdflib.term.URIRef('object\n')),
#  (rdflib.term.URIRef('Snowboarding'), rdflib.term.URIRef('Sport\n')),
#  (rdflib.term.URIRef('Jill'), rdflib.term.URIRef('Snowboarding\n'))]

# %% [markdown]
# ---
# Let's learn more about Donald Trump
# ----
#
# ![](http://vignette4.wikia.nocookie.net/animal-jam-clans-1/images/4/49/Donald-trump-hair-blown-by-wind.jpg/revision/latest?cb=20160203231507)

# %%
from IPython.display import IFrame

IFrame("http://dbpedia.org/page/Donald_Trump",
      width=800,
      height=600)
# Out:
#         <iframe
#             width="800"
#             height="600"
#             src="http://dbpedia.org/page/Donald_Trump"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %%
url = 'http://dbpedia.org/resource/Donald_Trump' # Note: 'resource', not 'page'

g = rdflib.Graph()
g.load(url)

# %%
# Take a peak at Subject, Predicate, Object Triples
print(next(g.subjects()), next(g.objects()), next(g.predicates()), sep=" | ")
# Out:
# http://dbpedia.org/resource/Donald_Trump | http://nl.dbpedia.org/resource/Donald_Trump | http://www.w3.org/2002/07/owl#sameAs

# %% [markdown]
# ![](http://assets.devx.com/articlefigs/19556.jpg)

# %% [markdown]
# __1__) Find Donald Trump's birth place within the graph object
#
# [RTFM](https://rdflib.readthedocs.org/en/stable/intro_to_graphs.html)

# %% [markdown]
# __2__) Add "Fred_Trump" as "relation of" to the graph object
#
# [RTFM](https://rdflib.readthedocs.org/en/stable/intro_to_creating_rdf.html)
# [Source](https://en.wikipedia.org/wiki/Donald_Trump)
#
# __HINT__: Check out http://dbpedia.org/ontology/

# %% [markdown]
# ---
# THERE MUST BE A BETTER WAY!
# ---

# %% [markdown]
# SPARQL is SQL for RDF graphs.
#
# SQL is a query langauge for tabular data (Pandas or databases)
#
# SPARQL attempts to match patterns in the graph

# %%
try:
    from SPARQLWrapper import SPARQLWrapper, JSON
except ImportError:
    import pip
    pip.main(["install", "SPARQLWrapper"])
    from SPARQLWrapper import SPARQLWrapper, JSON
# Out:
# Collecting SPARQLWrapper
#   Downloading SPARQLWrapper-1.7.6.tar.gz
# Requirement already satisfied (use --upgrade to upgrade): rdflib>=4.0 in /Users/brianspiering/anaconda/envs/py3_nlp/lib/python3.5/site-packages (from SPARQLWrapper)
# Collecting keepalive>=0.5 (from SPARQLWrapper)
#   Downloading keepalive-0.5.tar.gz
# Requirement already satisfied (use --upgrade to upgrade): isodate in /Users/brianspiering/anaconda/envs/py3_nlp/lib/python3.5/site-packages (from rdflib>=4.0->SPARQLWrapper)
# Requirement already satisfied (use --upgrade to upgrade): pyparsing in /Users/brianspiering/anaconda/envs/py3_nlp/lib/python3.5/site-packages (from rdflib>=4.0->SPARQLWrapper)
# Building wheels for collected packages: SPARQLWrapper, keepalive
#   Running setup.py bdist_wheel for SPARQLWrapper: started
#   Running setup.py bdist_wheel for SPARQLWrapper: finished with status 'done'
#   Stored in directory: /Users/brianspiering/Library/Caches/pip/wheels/25/f9/b1/1890e8eccdc8fbdba78e6e92b41e4fe4c6b9c9512ce57e0834
#   Running setup.py bdist_wheel for keepalive: started
#   Running setup.py bdist_wheel for keepalive: finished with status 'done'
#   Stored in directory: /Users/brianspiering/Library/Caches/pip/wheels/34/0a/41/2d4e439360f77d3ac7fdf950f4dcf230a65e742bc0299c1535
# Successfully built SPARQLWrapper keepalive
# Installing collected packages: keepalive, SPARQLWrapper
# Successfully installed SPARQLWrapper-1.7.6 keepalive-0.5

# %%
sparql = SPARQLWrapper("http://dbpedia.org/sparql")
sparql.setQuery("""
    SELECT ?pred ?object
    WHERE { <http://dbpedia.org/resource/Donald_Trump> ?pred ?object}
""")
sparql.setReturnFormat(JSON)
sparql.query().convert()
# Out:
# {'head': {'link': [], 'vars': ['pred', 'object']},
#  'results': {'bindings': [{'object': {'type': 'uri',
#      'value': 'http://dbpedia.org/class/yago/Administrator109770949'},
#     'pred': {'type': 'uri',
#      'value': 'http://www.w3.org/1999/02/22-rdf-syntax-ns#type'}},
#    {'object': {'type': 'uri',
#      'value': 'http://dbpedia.org/class/yago/Adult109605289'},
#     'pred': {'type': 'uri',
#      'value': 'http://www.w3.org/1999/02/22-rdf-syntax-ns#type'}},
#    {'object': {'type': 'uri',
#      'value': 'http://dbpedia.org/class/yago/Alumnus109786338'},
#     'pred': {'type': 'uri',
#      'value': 'http://www.w3.org/1999/02/22-rdf-syntax-ns#type'}},
#    {'object': {'type': 'uri',
#      'value': 'http://dbpedia.org/class/yago/AmericanBillionaires'},
#     'pred': {'type': 'uri',
#      'value': 'http://www.w3.org/1999/02/22-rdf-syntax-ns#type'}},
#    {'object': {'type': 'uri',
#      'value': 'http://dbpedia.org/class/yago/AmericanBusinessWriters'},
#     'pred': {'type': 'uri',
#      'value': 'http://www.w3.org/1999/02/22-rdf-syntax-ns#type'}},
#    {'object': {'type': 'uri',
#      'value': 'http://dbpedia.org/class/yago/AmericanChiefExecutives'},
#     'pred': {'type': 'uri',
#      'value': 'http://www.w3.org/1999/02/22-rdf-syntax-ns#type'}},
#    {'object': {'type': 'uri',
#      'value': 'http://dbpedia.org/class/yago/AmericanEnvironmentalists'},
#     'pred': {'type': 'uri',
#      'value': 'http://www.w3.org/1999/02/22-rdf-syntax-ns#type'}},
#    {'object': {'type': 'uri',
#      'value': 'http://dbpedia.org/class/yago/AmericanGameShowHosts'},
#     'pred': {'type': 'uri',
#      'value': 'http://www.w3.org/1999/02/22-rdf-syntax-ns#type'}},
#    {'object': {'type': 'uri',
#      'value': 'http://dbpedia.org/class/yago/AmericanPeopleOfGermanDescent'},
#     'pred': {'type': 'uri',
#      'value': 'http://www.w3.org/1999/02/22-rdf-syntax-ns#type'}},
#    {'object': {'type': 'uri',
#      'value': 'http://dbpedia.org/class/yago/AmericanPeopleOfScottishDescent'},
#     'pred': {'type': 'uri',
#      'value': 'http://www.w3.org/1999/02/22-rdf-syntax-ns#type'}},
#    {'object': {'type': 'uri',
#      'value': 'http://dbpedia.org/class/yago/AmericanSocialites'},
#     'pred': {'type': 'uri',
#      'value': 'http://www.w3.org/1999/02/22-rdf-syntax-ns#type'}},
#    {'object': {'type': 'uri',
#      'value': 'http://dbpedia.org/class/yago/Associate109816771'},
#     'pred': {'type': 'uri',
#      'value': 'http://www.w3.org/1999/02/22-rdf-syntax-ns#type'}},
#    {'object': {'type': 'uri',
#      'value': 'http://dbpedia.org/class/yago/Billionaire110529684'},
#     'pred': {'type': 'uri',
#      'value': 'http://www.w3.org/1999/02/22-rdf-syntax-ns#type'}},
#    {'object': {'type': 'uri',
#      'value': 'http://dbpedia.org/class/yago/CausalAgent100007347'},
#     'pred': {'type': 'uri',
#      'value': 'http://www.w3.org/1999/02/22-rdf-syntax-ns#type'}},
#    {'object': {'type': 'uri',
#      'value': 'http://dbpedia.org/class/yago/Communicator109610660'},
#     'pred': {'type': 'uri',
#      'value': 'http://www.w3.org/1999/02/22-rdf-syntax-ns#type'}},
#    {'object': {'type': 'uri',
#      'value': 'http://dbpedia.org/class/yago/Disputant109615465'},
#     'pred': {'type': 'uri',
#      'value': 'http://www.w3.org/1999/02/22-rdf-syntax-ns#type'}},
#    {'object': {'type': 'uri',
#      'value': 'http://dbpedia.org/class/yago/Environmentalist110060621'},
#     'pred': {'type': 'uri',
#      'value': 'http://www.w3.org/1999/02/22-rdf-syntax-ns#type'}},
#    {'object': {'type': 'uri',
#      'value': 'http://dbpedia.org/class/yago/Executive110069645'},
#     'pred': {'type': 'uri',
#      'value': 'http://www.w3.org/1999/02/22-rdf-syntax-ns#type'}},
#    {'object': {'type': 'uri',
#      'value': 'http://dbpedia.org/class/yago/Head110162991'},
#     'pred': {'type': 'uri',
#      'value': 'http://www.w3.org/1999/02/22-rdf-syntax-ns#type'}},
#    {'object': {'type': 'uri',
#      'value': 'http://dbpedia.org/class/yago/
}},
#    {'object': {'type': 'uri',
#      'value': 'http://www.huffingtonpost.com/donald-j-trump'},
#     'pred': {'type': 'uri',
#      'value': 'http://dbpedia.org/ontology/wikiPageExternalLink'}},
#    {'object': {'type': 'uri',
#      'value': 'http://www.w3.org/2006/03/wn/wn20/instances/synset-celebrity-noun-1'},
#     'pred': {'type': 'uri',
#      'value': 'http://dbpedia.org/property/wordnet_type'}},
#    {'object': {'type': 'uri',
#      'value': 'http://data.nytimes.com/N1211251261337738263'},
#     'pred': {'type': 'uri', 'value': 'http://www.w3.org/2002/07/owl#sameAs'}},
#    {'object': {'type': 'uri',
#      'value': 'http://fr.dbpedia.org/resource/Donald_Trump'},
#     'pred': {'type': 'uri', 'value': 'http://www.w3.org/2002/07/owl#sameAs'}},
#    {'object': {'type': 'uri',
#      'value': 'http://cs.dbpedia.org/resource/Donald_Trump'},
#     'pred': {'type': 'uri', 'value': 'http://www.w3.org/2002/07/owl#sameAs'}},
#    {'object': {'type': 'uri',
#      'value': 'http://de.dbpedia.org/resource/Donald_Trump'},
#     'pred': {'type': 'uri', 'value': 'http://www.w3.org/2002/07/owl#sameAs'}},
#    {'object': {'type': 'uri',
#      'value': 'http://el.dbpedia.org/resource/Ντόναλντ_Τραμπ'},
#     'pred': {'type': 'uri', 'value': 'http://www.w3.org/2002/07/owl#sameAs'}},
#    {'object': {'type': 'uri',
#      'value': 'http://es.dbpedia.org/resource/Donald_Trump'},
#     'pred': {'type': 'uri', 'value': 'http://www.w3.org/2002/07/owl#sameAs'}},
#    {'object': {'type': 'uri',
#      'value': 'http://id.dbpedia.org/resource/Donald_Trump'},
#     'pred': {'type': 'uri', 'value': 'http://www.w3.org/2002/07/owl#sameAs'}},
#    {'object': {'type': 'uri',
#      'value': 'http://it.dbpedia.org/resource/Donald_Trump'},
#     'pred': {'type': 'uri', 'value': 'http://www.w3.org/2002/07/owl#sameAs'}},
#    {'object': {'type': 'uri',
#      'value': 'http://ja.dbpedia.org/resource/ドナルド・トランプ'},
#     'pred': {'type': 'uri', 'value': 'http://www.w3.org/2002/07/owl#sameAs'}},
#    {'object': {'type': 'uri',
#      'value': 'http://ko.dbpedia.org/resource/도널드_트럼프'},
#     'pred': {'type': 'uri', 'value': 'http://www.w3.org/2002/07/owl#sameAs'}},
#    {'object': {'type': 'uri',
#      'value': 'http://nl.dbpedia.org/resource/Donald_Trump'},
#     'pred': {'type': 'uri', 'value': 'http://www.w3.org/2002/07/owl#sameAs'}},
#    {'object': {'type': 'uri',
#      'value': 'http://pl.dbpedia.org/resource/Donald_Trump'},
#     'pred': {'type': 'uri', 'value': 'http://www.w3.org/2002/07/owl#sameAs'}},
#    {'object': {'type': 'uri',
#      'value': 'http://pt.dbpedia.org/resource/Donald_Trump'},
#     'pred': {'type': 'uri', 'value': 'http://www.w3.org/2002/07/owl#sameAs'}},
#    {'object': {'type': 'uri',
#      'value': 'http://wikidata.dbpedia.org/resource/Q22686'},
#     'pred': {'type': 'uri', 'value': 'http://www.w3.org/2002/07/owl#sameAs'}},
#    {'object': {'type': 'uri', 'value': 'http://rdf.freebase.com/ns/m.0cqt90'},
#     'pred': {'type': 'uri', 'value': 'http://www.w3.org/2002/07/owl#sameAs'}},
#    {'object': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q22686'},
#     'pred': {'type': 'uri', 'value': 'http://www.w3.org/2002/07/owl#sameAs'}},
#    {'object': {'type': 'uri',
#      'value': 'http://yago-knowledge.org/resource/Donald_Trump'},
#     'pred': {'type': 'uri', 'value': 'http://www.w3.org/2002/07/owl#sameAs'}},
#    {'object': {'type': 'uri',
#      'value': 'http://dbpedia.org/resource/Fordham_University'},
#     'pred': {'type': 'uri', 'value': 'http://dbpedia.org/property/almaMater'}},
#    {'object': {'type': 'literal',
#      'value': 'University of Pennsylvania (  )',
#      'xml:lang': 'en'},
#     'pred': {'type': 'uri', 'value': 'http://dbpedia.org/property/almaMater'}},
#    {'object': {'datatype': 'http://www.w3.org/2001/XMLSchema#date',
#      'type': 'typed-literal',
#      'value': '1946-06-14'},
#     'pred': {'type': 'uri', 'value': 'http://dbpedia.org/property/birthDate'}},
#    {'object': {'type': 'literal',
#      'value': 'Donald John Trump',
#      'xml:lang': 'en'},
#     'pred': {'type': 'uri', 'value': 'http://dbpedia.org/property/birthName'}},
#    {'object': {'type': 'literal',
#      'value': 'Donald Jr., Ivanka, Eric, Tiffany, Barron',
#      'xml:lang': 'en'},
#     'pred': {'type': 'uri', 'value': 'http://dbpedia.org/property/children'}},
#    {'object': {'datatype': 'http://www.w3.org/2001/XMLSchema#gMonthDay',
#      'type': 'typed-literal',
#      'value': '--04-22'},
#     'pred': {'type': 'uri', 'value': 'http://dbpedia.org/property/image'}},
#    {'object': {'type': 'literal',
#      'value': 'Donald Trump star Hollywood Walk of Fame.JPG',
#      'xml:lang': 'en'},
#     'pred': {'type': 'uri', 'value': 'http://dbpedia.org/property/image'}},
#    {'object': {'datatype': 'http://dbpedia.org/datatype/usDollar',
#      'type': 'typed-literal',
#      'value': '4.0E9'},
#     'pred': {'type': 'uri', 'value': 'http://dbpedia.org/property/networth'}},
#    {'object': {'type': 'literal',
#      'value': '* Chairman and president of The Trump Organization\n* Chairman of Trump Plaza Associates, LLC\n* Chairman of Trump Atlantic City Associates\n* Host of The Apprentice',
#      'xml:lang': 'en'},
#     'pred': {'type': 'uri',
#      'value': 'http://dbpedia.org/property/occupation'}},
#    {'object': {'type': 'literal',
#      'value': 'CEO of Trump Entertainment Resorts',
#      'xml:lang': 'en'},
#     'pred': {'type': 'uri', 'value': 'http://dbpedia.org/property/office'}},
#    {'object': {'type': 'literal',
#      'value': 'Chairman of The Trump Organization',
#      'xml:lang': 'en'},
#     'pred': {'type': 'uri', 'value': 'http://dbpedia.org/property/office'}},
#    {'object': {'type': 'uri',
#      'value': 'http://dbpedia.org/resource/Fred_Trump'},
#     'pred': {'type': 'uri', 'value': 'http://dbpedia.org/property/parents'}},
#    {'object': {'type': 'literal',
#      'value': 'Mary Anne MacLeod Trump',
#      'xml:lang': 'en'},
#     'pred': {'type': 'uri', 'value': 'http://dbpedia.org/property/parents'}},
#    {'object': {'type': 'literal', 'value': 'Reform', 'xml:lang': 'en'},
#     'pred': {'type': 'uri', 'value': 'http://dbpedia.org/property/party'}},
#    {'object': {'type': 'literal', 'value': 'Democratic', 'xml:lang': 'en'},
#     'pred': {'type': 'uri', 'value': 'http://dbpedia.org/property/party'}},
#    {'object': {'type': 'literal', 'value': 'Independent', 'xml:lang': 'en'},
#     'pred': {'type': 'uri', 'value': 'http://dbpedia.org/property/party'}},
#    {'object': {'type': 'literal', 'value': 'Republican', 'xml:lang': 'en'},
#     'pred': {'type': 'uri', 'value': 'http://dbpedia.org/property/party'}},
#    {'object': {'type': 'literal',
#      'value': 'Position established',
#      'xml:lang': 'en'},
#     'pred': {'type': 'uri',
#      'value': 'http://dbpedia.org/property/predecessor'}},
#    {'object': {'type': 'uri',
#      'value': 'http://dbpedia.org/resource/Presbyterianism'},
#     'pred': {'type': 'uri', 'value': 'http://dbpedia.org/property/religion'}},
#    {'object': {'datatype': 'http://dbpedia.org/datatype/usDollar',
#      'type': 'typed-literal',
#      'value': '2.5E8'},
#     'pred': {'type': 'uri', 'value': 'http://dbpedia.org/property/salary'}},
#    {'object': {'type': 'literal',
#      'value': 'Donald Trump Signature.svg',
#      'xml:lang': 'en'},
#     'pred': {'type': 'uri', 'value': 'http://dbpedia.org/property/signature'}},
#    {'object': {'type': 'literal', 'value': 'Robert Griffin', 'xml:lang': 'en'},
#     'pred': {'type': 'uri', 'value': 'http://dbpedia.org/property/successor'}},
#    {'object': {'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'type': 'typed-literal',
#      'value': '2004'},
#     'pred': {'type': 'uri', 'value': 'http://dbpedia.org/property/termEnd'}},
#    {'object': {'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'type': 'typed-literal',
#      'value': '1971'},
#     'pred': {'type': 'uri', 'value': 'http://dbpedia.org/property/termStart'}},
#    {'object': {'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'type': 'typed-literal',
#      'value': '1995'},
#     'pred': {'type': 'uri', 'value': 'http://dbpedia.org/property/termStart'}},
#    {'object': {'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'type': 'typed-literal',
#      'value': '220'},
#     'pred': {'type': 'uri', 'value': 'http://dbpedia.org/property/width'}},
#    {'object': {'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'type': 'typed-literal',
#      'value': '1995'},
#     'pred': {'type': 'uri', 'value': 'http://dbpedia.org/property/years'}},
#    {'object': {'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'type': 'typed-literal',
#      'value': '1968'},
#     'pred': {'type': 'uri',
#      'value': 'http://dbpedia.org/property/yearsActive'}},
#    {'object': {'datatype': 'http://www.w3.org/2001/XMLSchema#gMonthDay',
#      'type': 'typed-literal',
#      'value': '--04-22'},
#     'pred': {'type': 'uri', 'value': 'http://dbpedia.org/property/caption'}},
#    {'object': {'type': 'literal',
#      'value': 'Trump signs loyalty pledge, September 2015',
#      'xml:lang': 'en'},
#     'pred': {'type': 'uri', 'value': 'http://dbpedia.org/property/caption'}},
#    {'object': {'type': 'literal',
#      'value': "Trump's star on the Hollywood Walk of Fame",
#      'xml:lang': 'en'},
#     'pred': {'type': 'uri', 'value': 'http://dbpedia.org/property/caption'}},
#    {'object': {'type': 'literal',
#      'value': 'Chief Executive Officer of Trump Hotels and Casino Resorts',
#      'xml:lang': 'en'},
#     'pred': {'type': 'uri', 'value': 'http://dbpedia.org/property/title'}},
#    {'object': {'type': 'literal', 'value': 'Donald Trump', 'xml:lang': 'en'},
#     'pred': {'type': 'uri',
#      'value': 'http://www.w3.org/2000/01/rdf-schema#label'}},
#    {'object': {'type': 'literal', 'value': 'دونالد ترامب', 'xml:lang': 'ar'},
#     'pred': {'type': 'uri',
#      'value': 'http://www.w3.org/2000/01/rdf-schema#label'}},
#    {'object': {'type': 'literal', 'value': 'Donald Trump', 'xml:lang': 'de'},
#     'pred': {'type': 'uri',
#      'value': 'http://www.w3.org/2000/01/rdf-schema#label'}},
#    {'object': {'type': 'literal', 'value': 'Donald Trump', 'xml:lang': 'es'},
#     'pred': {'type': 'uri',
#      'value': 'http://www.w3.org/2000/01/rdf-schema#label'}},
#    {'object': {'type': 'literal', 'value': 'Donald Trump', 'xml:lang': 'fr'},
#     'pred': {'type': 'uri',
#      'value': 'http://www.w3.org/2000/01/rdf-schema#label'}},
#    {'object': {'type': 'literal', 'value': 'Donald Trump', 'xml:lang': 'it'},
#     'pred': {'type': 'uri',
#      'value': 'http://www.w3.org/2000/01/rdf-schema#label'}},
#    {'object': {'type': 'literal', 'value': 'ドナルド・トランプ', 'xml:lang': 'ja'},
#     'pred': {'type': 'uri',
#      'value': 'http://www.w3.org/2000/01/rdf-schema#label'}},
#    {'object': {'type': 'literal', 'value': 'Donald Trump', 'xml:lang': 'nl'},
#     'pred': {'type': 'uri',
#      'value': 'http://www.w3.org/2000/01/rdf-schema#label'}},
#    {'object': {'type': 'literal', 'value': 'Donald Trump', 'xml:lang': 'pl'},
#     'pred': {'type': 'uri',
#      'value': 'http://www.w3.org/2000/01/rdf-schema#label'}},
#    {'object': {'type': 'literal', 'value': 'Donald Trump', 'xml:lang': 'pt'},
#     'pred': {'type': 'uri',
#      'value': 'http://www.w3.org/2000/01/rdf-schema#label'}},
#    {'object': {'type': 'literal', 'value': '唐納德·川普', 'xml:lang': 'zh'},
#     'pred': {'type': 'uri',
#      'value': 'http://www.w3.org/2000/01/rdf-schema#label'}},
#    {'object': {'type': 'liter
},
#     'pred': {'type': 'uri',
#      'value': 'http://www.w3.org/2000/01/rdf-schema#comment'}},
#    {'object': {'type': 'literal',
#      'value': 'До́нальд Джон Трамп (англ. Donald John Trump; род. 14 июня 1946 года, Куинс, штат Нью-Йорк, США) — американский бизнесмен, известная личность на телевидении и радио, писатель. Он также является президентом компании Trump Organization — крупной строительной компании в США и основателем компании Trump Entertainment Resorts, которая управляет многочисленными казино и отелями по всему миру.',
#      'xml:lang': 'ru'},
#     'pred': {'type': 'uri',
#      'value': 'http://www.w3.org/2000/01/rdf-schema#comment'}},
#    {'object': {'type': 'uri',
#      'value': 'http://dbpedia.org/resource/Donald_Trump_presidential_campaign,_2016'},
#     'pred': {'type': 'uri',
#      'value': 'http://www.w3.org/2000/01/rdf-schema#seeAlso'}},
#    {'object': {'type': 'uri', 'value': 'http://dbpedia.org/resource/2016'},
#     'pred': {'type': 'uri',
#      'value': 'http://www.w3.org/2000/01/rdf-schema#seeAlso'}},
#    {'object': {'type': 'literal', 'value': 'Donald Trump', 'xml:lang': 'en'},
#     'pred': {'type': 'uri', 'value': 'http://xmlns.com/foaf/0.1/name'}},
#    {'object': {'type': 'uri', 'value': 'https://www.donaldjtrump.com/'},
#     'pred': {'type': 'uri', 'value': 'http://xmlns.com/foaf/0.1/homepage'}},
#    {'object': {'type': 'uri', 'value': 'http://www.donaldjtrump.com'},
#     'pred': {'type': 'uri', 'value': 'http://xmlns.com/foaf/0.1/homepage'}},
#    {'object': {'type': 'literal', 'value': 'Donald Trump', 'xml:lang': 'en'},
#     'pred': {'type': 'uri', 'value': 'http://dbpedia.org/property/name'}},
#    {'object': {'type': 'uri',
#      'value': 'http://commons.wikimedia.org/wiki/Special:FilePath/Donald_Trump_September_3_2015.jpg'},
#     'pred': {'type': 'uri', 'value': 'http://xmlns.com/foaf/0.1/depiction'}},
#    {'object': {'type': 'uri',
#      'value': 'http://en.wikipedia.org/wiki/Donald_Trump'},
#     'pred': {'type': 'uri',
#      'value': 'http://xmlns.com/foaf/0.1/isPrimaryTopicOf'}},
#    {'object': {'type': 'uri',
#      'value': 'http://commons.wikimedia.org/wiki/Special:FilePath/Donald_Trump_September_3_2015.jpg?width=300'},
#     'pred': {'type': 'uri', 'value': 'http://dbpedia.org/ontology/thumbnail'}},
#    {'object': {'type': 'uri',
#      'value': 'http://en.wikipedia.org/wiki/Donald_Trump?oldid=683777212'},
#     'pred': {'type': 'uri',
#      'value': 'http://www.w3.org/ns/prov#wasDerivedFrom'}},
#    {'object': {'type': 'literal',
#      'value': 'دونالد جون ترامب (ولد في 14 يونيو 1946) هو رجل أعمال وملياردير ومرشح رئاسي وشخصية تلفزيون ومؤلف أمريكي. وهو الرئيس والمدير التنفيذي لمنظمة ترامب العقارية، ومقرها في الولايات المتحدة وهو أيضاً المؤسس لمنتجعات ترامب الترفيهية، التي تدير العديد من الكازينوهات، والفنادق وملاعب الغولف والمنشآت الأخرى في جميع أنحاء العالم. ساعدت نمط حياة ترامب وانتشار علامته التجارية وطريقته الصريحة في التعامل مع السياسية في الحديث على جعله من المشاهير في كل من الولايات المتحدة والعالم على مدى سنوات وحتى الآن، زاد من نجاح ترامب تقديمه لبرنامح الواقع على أن بي سي، المبتدئ The Apprentice.دونالد هو الابن الرابع لعائلة مكونة من خمسة أطفال أباهم فريد ترامب، أحد الأثرياء وملاك العقار في مدينة نيويورك. وقد تأثر دونالد تأثرا شديدا بوالده فاّل به المطاف إلى جعل مهنته في مجال التطوير العقاري،  وعند تخرجه من كلية وارتون في جامعة بنسلفانيا في عام 1968، انضم دونالد ترامب إلى شركة والده، مؤسسة ترامب.بدأ حياته العملية بتجديد للفندق الكومودور في فندق غراند حياة مع عائلة بريتزكر، ثم تابع مع برج ترامب في مدينة نيويورك وغيرها من المشاريع العديدة في المجمعات السكنية. في وقت لاحق انتقل إلى التوسع في صناعة الطيران (شراء شركة ايسترن شتل،  واتلانتيك سيتي كازينو، بما في ذلك شراء كازينو تاج محل من عائلة كروسبي، ولكن مشروع الكازينو افلس. وقد أدى هذا التوسع في الأعمال الت
#      'xml:lang': 'en'},
#     'pred': {'type': 'uri', 'value': 'http://dbpedia.org/ontology/abstract'}},
#    {'object': {'type': 'literal',
#      'value': 'До́нальд Джон Трамп (англ. Donald John Trump; род. 14 июня 1946 года, Куинс, штат Нью-Йорк, США) — американский бизнесмен, известная личность на телевидении и радио, писатель. Он также является президентом компании Trump Organization — крупной строительной компании в США и основателем компании Trump Entertainment Resorts, которая управляет многочисленными казино и отелями по всему миру. Трамп стал знаменитостью благодаря экстравагантному стилю жизни и откровенному стилю общения, а также своему успешному реалити-шоу «Кандидат», где он выступает и как исполнительный продюсер, и как ведущий.В сентябре 2010 года Дональд Трамп заявил, что «всерьез обдумывает» возможность баллотироваться на пост президента США в 2012 году. На выборах 2008 года он поддерживал кандидата от Республиканской партии Джона Маккейна, который, в итоге, проиграл демократу Бараку Обаме. 16 июня 2015 года Дональд Трамп объявил о вступлении в борьбу за пост президента США в 2016 году.',
#      'xml:lang': 'ru'},
#     'pred': {'type': 'uri', 'value': 'http://dbpedia.org/ontology/abstract'}},
#    {'object': {'datatype': 'http://www.w3.org/2001/XMLSchema#gYear',
#      'type': 'typed-literal',
#      'value': '1968'},
#     'pred': {'type': 'uri',
#      'value': 'http://dbpedia.org/ontology/activeYearsStartYear'}},
#    {'object': {'type': 'uri',
#      'value': 'http://dbpedia.org/resource/Fordham_University'},
#     'pred': {'type': 'uri', 'value': 'http://dbpedia.org/ontology/almaMater'}},
#    {'object': {'type': 'uri',
#      'value': 'http://dbpedia.org/resource/University_of_Pennsylvania'},
#     'pred': {'type': 'uri', 'value': 'http://dbpedia.org/ontology/almaMater'}},
#    {'object': {'type': 'literal',
#      'value': 'Donald John Trump',
#      'xml:lang': 'en'},
#     'pred': {'type': 'uri', 'value': 'http://dbpedia.org/ontology/birthName'}},
#    {'object': {'datatype': 'http://www.w3.org/2001/XMLSchema#gYear',
#      'type': 'typed-literal',
#      'value': '1946'},
#     'pred': {'type': 'uri', 'value': 'http://dbpedia.org/ontology/birthYear'}},
#    {'object': {'type': 'uri',
#      'value': 'http://dbpedia.org/resource/Eric_Trump'},
#     'pred': {'type': 'uri', 'value': 'http://dbpedia.org/ontology/child'}},
#    {'object': {'type': 'uri',
#      'value': 'http://dbpedia.org/resource/Ivanka_Trump'},
#     'pred': {'type': 'uri', 'value': 'http://dbpedia.org/ontology/child'}},
#    {'object': {'type': 'uri',
#      'value': 'http://dbpedia.org/resource/Donald_Trump,_Jr.'},
#     'pred': {'type': 'uri', 'value': 'http://dbpedia.org/ontology/child'}},
#    {'object': {'datatype': 'http://dbpedia.org/datatype/usDollar',
#      'type': 'typed-literal',
#      'value': '4.0E9'},
#     'pred': {'type': 'uri', 'value': 'http://dbpedia.org/ontology/networth'}},
#    {'object': {'type': 'uri',
#      'value': 'http://dbpedia.org/resource/Donald_Trump__1'},
#     'pred': {'type': 'uri',
#      'value': 'http://dbpedia.org/ontology/occupation'}},
#    {'object': {'type': 'uri',
#      'value': 'http://dbpedia.org/resource/The_Trump_Organization'},
#     'pred': {'type': 'uri',
#      'value': 'http://dbpedia.org/ontology/occupation'}},
#    {'object': {'type': 'uri',
#      'value': 'http://dbpedia.org/resource/The_Apprentice_(U.S._TV_series)'},
#     'pred': {'type': 'uri',
#      'value': 'http://dbpedia.org/ontology/occupation'}},
#    {'object': {'type': 'uri',
#      'value': 'http://dbpedia.org/resource/Fred_Trump'},
#     'pred': {'type': 'uri', 'value': 'http://dbpedia.org/ontology/parent'}},
#    {'object': {'type': 'uri',
#      'value': 'http://dbpedia.org/resource/Independent_politician'},
#     'pred': {'type': 'uri', 'value': 'http://dbpedia.org/ontology/party'}},
#    {'object': {'type': 'uri',
#      'value': 'http://dbpedia.org/resource/Democratic_Party_(United_States)'},
#     'pred': {'type': 'uri', 'value': 'http://dbpedia.org/ontology/party'}},
#    {'object': {'type': 'uri',
#      'value': 'http://dbpedia.org/resource/Reform_Party_of_the_United_States_of_America'},
#     'pred': {'type': 'uri', 'value': 'http://dbpedia.org/ontology/party'}},
#    {'object': {'type': 'uri',
#      'value': 'http://dbpedia.org/resource/Republican_Party_(United_States)'},
#     'pred': {'type': 'uri', 'value': 'http://dbpedia.org/ontology/party'}},
#    {'object': {'type': 'uri',
#      'value': 'http://dbpedia.org/resource/Presbyterianism'},
#     'pred': {'type': 'uri', 'value': 'http://dbpedia.org/ontology/religion'}},
#    {'object': {'datatype': 'http://dbpedia.org/datatype/usDollar',
#      'type': 'typed-literal',
#      'value': '2.5E8'},
#     'pred': {'type': 'uri', 'value': 'http://dbpedia.org/ontology/salary'}},
#    {'object': {'type': 'bnode', 'value': 'nodeID://b27055860'},
#     'pred': {'type': 'uri', 'value': 'http://purl.org/voc/vrank#hasRank'}}],
#   'distinct': False,
#   'ordered': True}}

# %% [markdown]
# __3__) Find Donald Trump's birth place within the query results
#
# [Help](https://www.w3.org/2009/Talks/0615-qbe/)
#
# __HINTS__: Write your query as regular SQL then rewrite in SPARQL

# %% [markdown]
# __4__) Using sparql, walk the graph to find a list of all the people that are also born where Donald Trump was born.
#
# It is okay for it take multiple steps.

# %% [markdown]
# ---
# Optional
# ----

# %% [markdown]
# Parse the abstract with str methods and find as many associated elements in the RDF graph.

# %% [markdown]
# Which ones were easy?
#
# Which ones were hard?
#
# How would you do the inverse, go from a RDF to a narrative summary?

# %% [markdown]
# <br>
# <br>
# ----
