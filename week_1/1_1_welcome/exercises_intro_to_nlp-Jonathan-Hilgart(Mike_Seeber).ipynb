# %% [markdown]
# Exercises: Introduction to NLP in Python
# ===
#
# ![](http://static1.squarespace.com/static/538cea80e4b00f1fad490c1b/54668a77e4b00fb778d22a34/54668d8ae4b00fb778d2859c/1416007413413/NLTK.png)

# %%
reset -fs

# %%
import nltk

# %%
print('hi')
# Out:
# hi

# %%
nltk?
# Out:
# Object `nltk` not found.

# %% [markdown]
# ---
# What is NLTK?
# ---
#
# Natural Language Toolkit (nltk) is a Python package for NLP
#
# __Pros__:
#
# - Common
# - Functionality
#
# __Cons__:
#
# - Too academic
# - Too slow
# - Awkward API
#
# We'll be using alot NLTK (but also other more modern libraries).

# %% [markdown]
# ---
# What are Corpus / Corpora?
# ---
#
# > a collection of written texts, especially the entire works of a particular author or a body of writing on a particular subject.
#
# The rest of the world call them "documents".
#
# I have curated corpora for you.

# %% [markdown]
# ---
# 0) Download `nltk` corpora
# ---
# ![](images/download_all_the_corpora.png)
# You have most of the `nltk` from environment setup. You will need all of the toolbox, including the corpora

# %%
nltk.download('all')
# Out:
# [nltk_data] Downloading collection 'all'
# [nltk_data]    |
# [nltk_data]    | Downloading package abc to
# [nltk_data]    |     /Users/jonathanhilgart/nltk_data...
# [nltk_data]    |   Unzipping corpora/abc.zip.
# [nltk_data]    | Downloading package alpino to
# [nltk_data]    |     /Users/jonathanhilgart/nltk_data...
# [nltk_data]    |   Unzipping corpora/alpino.zip.
# [nltk_data]    | Downloading package biocreative_ppi to
# [nltk_data]    |     /Users/jonathanhilgart/nltk_data...
# [nltk_data]    |   Unzipping corpora/biocreative_ppi.zip.
# [nltk_data]    | Downloading package brown to
# [nltk_data]    |     /Users/jonathanhilgart/nltk_data...
# [nltk_data]    |   Unzipping corpora/brown.zip.
# [nltk_data]    | Downloading package brown_tei to
# [nltk_data]    |     /Users/jonathanhilgart/nltk_data...
# [nltk_data]    |   Unzipping corpora/brown_tei.zip.
# [nltk_data]    | Downloading package cess_cat to
# [nltk_data]    |     /Users/jonathanhilgart/nltk_data...
# ...

# %% [markdown]
# ----

# %%
# Double check that you have the corpora
from nltk.corpus import genesis

assert genesis.words()[:5] == ['In', 'the', 'beginning', 'God', 'created']

# %% [markdown]
# ---
# 1) Zipf's Law:
# ---
#
# Zipf's Law (not a real "law") is a NLP phenomena:
#
# >  the frequency of any word is inversely proportional to its rank in the frequency table.
#
# or in Plain English:
#
# > the most frequent word will occur about twice as often as the second most frequent word
#
# For example:
#
# |Word  |  Rank | Frequency |
# |:-------:|:------:| :---:|
# | “the”   | 1st |30k |
# | "of" | 2nd | 15k |
# | "and" |  3rd | 7.5k |
#
# __Word by frequency count:__
# ![](images/graph-zipf.png)

# %% [markdown]
# NLP (or Data Science) WorkFlow
# ------
#
# 1. Ask
# 2. Acquire
# 3. Process
# 4. Model
# 5. Deliver

# %% [markdown]
# TODO: Load a nltk corpus

# %%
from nltk.corpus import genesis
type(genesis)
# Out:
# nltk.corpus.reader.plaintext.PlaintextCorpusReader

# %% [markdown]
# TODO: Get word counts as a dict

# %%
import collections

# %%
collections.Counter(genesis.words())
# Out:
# Counter({'puhkesivat': 1,
#          'cash': 1,
#          'Kenen': 2,
#          'resin': 1,
#          'Maa': 4,
#          ',)': 1,
#          'valeur': 1,
#          'conheceram': 3,
#          'pilvissä': 2,
#          'ditut': 1,
#          'joking': 1,
#          'Gaham': 7,
#          'bakr': 1,
#          'maata': 22,
#          'Starke': 1,
#          'Trankopfer': 1,
#          'eux': 43,
#          'hänkin': 3,
#          'Empêchons': 1,
#          'terrestres': 1,
#          'cozeu': 1,
#          'Multiplicarei': 2,
#          'united': 2,
#          'wessen': 1,
#          'gesetzt': 8,
#          'tied': 1,
#          'trompa': 1,
#          'född': 2,
#          'åkerjorden': 2,
#          'saith': 5,
#          'hyvänsä': 1,
#          'Zimran': 3,
#          'ångrade': 1,
#          'Barmherzigkeit': 8,
#          'Rädda': 1,
#          'taloutta': 1,
#          'miekkasi': 1,
#          'irmãos': 80,
#          'Sept': 4,
#          'siclo': 1,
# ...

# %%
word_dict = {}
for word in genesis.words():
    if word in word_dict:
        word_dict[word]+=1
    else:
        word_dict[word]=1

# %%
word_dict
# Out:
# {'voimakkaat': 2,
#  'cash': 1,
#  'Kenen': 2,
#  'resin': 1,
#  'Maa': 4,
#  'obedeceram': 1,
#  'valeur': 1,
#  'conheceram': 3,
#  'pilvissä': 2,
#  'ditut': 1,
#  'joking': 1,
#  'Gaham': 7,
#  'dura': 1,
#  'bakr': 1,
#  'maata': 22,
#  'Starke': 1,
#  'Trankopfer': 1,
#  'eux': 43,
#  'hänkin': 3,
#  'Empêchons': 1,
#  'terrestres': 1,
#  'vise': 1,
#  'amargo': 1,
#  'Multiplicarei': 2,
#  'united': 2,
#  'wessen': 1,
#  'gesetzt': 8,
#  'tied': 1,
#  'trompa': 1,
#  'rentrer': 2,
#  'åkerjorden': 2,
#  'saith': 5,
#  'hyvänsä': 1,
#  'Zimran': 3,
#  'ångrade': 1,
#  'sexton': 1,
#  'Barmherzigkeit': 8,
#  'Rädda': 1,
#  'taloutta': 1,
#  'miekkasi': 1,
#  'Moab': 10,
#  'Sept': 4,
#  'siclo': 1,
#  'wilderness': 14,
#  'Whial': 1,
#  'Determina': 1,
#  'leipuri': 2,
#  'Jst': 1,
#  'Mahalatin': 1,
#  'burnt': 17,
#  'Desert': 1,
#  'poursuis': 1,
#  'kerrottiin': 1,
#  'würdest': 1,
#  'rikedom': 2,
#  'avundades': 2,
#  'multipliez': 5,
#  'nousivat': 5,
#  'troisième': 10,
# ...

# %% [markdown]
# Sort word counts (done for you)

# %%
import operator

# %%
word_counts_sorted = sorted(word_dict.items(), 
                            key=operator.itemgetter(1),
                            reverse=True)

# %%
assert word_counts_sorted[1] == ('.', 11069)

# %%
word_counts_sorted[0:10]
# Out:
# [(',', 22643),
#  ('.', 11069),
#  ('the', 4642),
#  ('and', 4368),
#  (':', 3636),
#  (';', 3589),
#  ("'", 3198),
#  ('de', 3160),
#  ('of', 2824),
#  ('a', 2372)]

# %% [markdown]
# TODO: What is the data structure of word_counts_sorted?

# %%
# Tuple

# %% [markdown]
# Take a only the first couple to plot

# %%
sample = word_counts_sorted[:25]
sample[0][0]
# Out:
# ','

# %% [markdown]
# Plot frequency counts

# %%
import matplotlib.pyplot as plt
import numpy as np

# %matplotlib inline

# %%
TODO: Finish code. Think about efficent code
# Out:
#   File "<ipython-input-17-1828480bb2d8>", line 1
#     TODO: Finish code. Think about efficent code
#         ^
# SyntaxError: invalid syntax

# %%
labels, values = [ combo[0] for (combo) in sample],[ combo[1] for combo in sample] # TODO: Unpack sample. Think about efficent code

# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib
# /Users/jonathanhilgart/anaconda/envs/nlp/lib/python3.5/site-packages/IPython/core/magics/pylab.py:161: UserWarning: pylab import has clobbered these variables: ['sample']
# `%matplotlib` prevents importing * from pylab and numpy
#   "\n`%matplotlib` prevents importing * from pylab and numpy"

# %%
indexes = np.arange(len(labels))
width = 1

plt.bar(indexes, values, width)
plt.xticks(indexes + width * 0.5, labels)
plt.show()

# %% [markdown]
# TODO: Does this confirm to Zipf Law? Why or Why not?

# %%
# This does not conform to Zipf's law because the the the number one most frequent word. And, is
# the second most frequent word because does not have half the number of occurances.

# %% [markdown]
# ----
# Challenge Exercises
# -----

# %%
sample = word_counts_sorted[:100]

# %% [markdown]
# TODO: Remove punctuation and plot the results

# %%
stripped_sample = [item[0].strip(",.!?;:") for item in sample]

# %%
stripped_list = []
punctuation = [',','.','!',"'",":",";","-",'"',"?","&",".╜"]

for item in sample:
    if item[0] in punctuation:
        pass
    else:
        stripped_list.append(item)

# %%
#stripped_list

# %%
labels_strip, values_strip = [ combo[0] for (combo) in stripped_list],[ combo[1] for combo in stripped_list]

indexes_strip = np.arange(len(labels_strip))
width = 1

plt.figure(figsize=([20,5]))
plt.bar(indexes_strip, values_strip, width)
plt.xticks(indexes_strip + width * .5, labels_strip)

plt.show()

# %% [markdown]
# TODO: Plot word frequency against word rank.
#
# <details><summary>
# Click here for a hint...
# </summary>
# Plot it on log/log scale
# </details>

# %%
import pandas as pd

# %%
stripped_list
# Out:
# [('the', 4642),
#  ('and', 4368),
#  ('de', 3160),
#  ('of', 2824),
#  ('a', 2372),
#  ('e', 2353),
#  ('und', 2010),
#  ('och', 1839),
#  ('to', 1805),
#  ('in', 1625),
#  ('et', 1593),
#  ('ja', 1546),
#  ('que', 1432),
#  ('he', 1354),
#  ('his', 1307),
#  ('And', 1271),
#  ('I', 1189),
#  ('o', 1092),
#  ('that', 968),
#  ('said', 962),
#  ('E', 960),
#  ('me', 939),
#  ('à', 939),
#  ('An', 907),
#  ('him', 902),
#  ('till', 815),
#  ('s', 803),
#  ('{', 799),
#  ('du', 793),
#  ('la', 792),
#  ('was', 785),
#  ('will', 773),
#  ('."', 769),
#  ('}', 736),
#  ('son', 727),
#  ('die', 717),
#  ('da', 713),
#  ('you', 705),
#  ('my', 704),
#  ('en', 704),
#  ('on', 703),
#  ('Abraham', 698),
#  ('i', 683),
#  ('le', 680),
#  ('szlig', 677),
#  ('se', 668),
#  ('all', 655),
#  ('han', 653),
#  ('it', 633),
#  ('den', 629),
#  ('der', 626),
#  ('for', 624),
#  ('Och', 621),
#  ('Jacob', 619),
#  ('les', 616),
#  ('with', 613),
#  ('l', 603),
#  ('is', 603),
#  ('unto', 597),
# ...

# %%
pd.DataFrame(stripped_list).plot()

# %%
#Only the first 100 words. More of a linear relationship
plt.loglog([item[1] for item in stripped_list])

# %%
#All the words in the corpus
plt.loglog([item[1] for item in word_counts_sorted ])

# %% [markdown]
# TODO: Describe the what the plot tells you about the data

# %%
# This plot shows us the occurance of each word relative to the rank of that word (number of times it appears).
#The log graph shows a linear relationship between the word counts and the rank of the words (on the log scale)

# %% [markdown]
# TODO: How does your result compare to Wikipedia?
#
# ![](https://upload.wikimedia.org/wikipedia/commons/b/b9/Wikipedia-n-zipf.png)

# %%
#Our graph pretty much matches Wikipedia's graph. At the end of the model you can see that there is a 
#slight dip in the linear relationship (a curve)

# %% [markdown]
# TODO: Fit and plot a linear model to the data (rank vs frequency)

# %%
import statsmodels.api as smf

# %%
stripped_list[0:10]
stripped_list[:10]
# Out:
# [('the', 4642),
#  ('and', 4368),
#  ('de', 3160),
#  ('of', 2824),
#  ('a', 2372),
#  ('e', 2353),
#  ('und', 2010),
#  ('och', 1839),
#  ('to', 1805),
#  ('in', 1625)]

# %%
#Get the index, and the log of the values
rank_strip= list(range(1,len(stripped_list)+1))
rank_strip
log_values = [log(item[1]) for item in stripped_list]

# %%
X.head()
# Out:
#    frequency_log  constant  log_values
# 0              0         1    8.442901
# 1              1         1    8.382061
# 2              2         1    8.058327
# 3              3         1    7.945910
# 4              4         1    7.771489

# %%
#Using frequency to predict rank 
X_log = pd.DataFrame(log(rank_strip),columns=['frequency_log'])
#X_log.drop(['log_values'],axis=0)
y_log = log_values



X_log['constant']=1

model_log = smf.OLS(y_log,X_log).fit()
model_log.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared:                       0.988
# Model:                            OLS   Adj. R-squared:                  0.987
# Method:                 Least Squares   F-statistic:                     6878.
# Date:                Mon, 24 Oct 2016   Prob (F-statistic):           1.37e-84
# Time:                        13:00:23   Log-Likelihood:                 122.55
# No. Observations:                  89   AIC:                            -241.1
# Df Residuals:                      87   BIC:                            -236.1
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                     coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ---------------------------------------------------------------------------------
# ...

# %%
logged_df = X_log
logged_df['log_values']=y_log

# %%
plt.plot(model_log.fittedvalues)

# %%
import seaborn as sns

# %%
#Log of X versus log of y
sns.lmplot('frequency_log','log_values',logged_df)

# %% [markdown]
# TODO: Is a linear model a good model for the data? Why or Why not?

# %%
# This is a very good linear model, with a r^2 of 98.8% This means that98.8 of the data variance is explained by our
#dependent variable (frequency).

# %% [markdown]
# Summary
# -----
#
# 1. Ask the right question
# 2. Acquire the data
# 3. Process: clean and organize
# 4. Model: statistics and machine learning
# 5. Deliver: add value, report, presentation, or code/API

# %% [markdown]
# <br>
# <br>
# <br>
#
# ----
